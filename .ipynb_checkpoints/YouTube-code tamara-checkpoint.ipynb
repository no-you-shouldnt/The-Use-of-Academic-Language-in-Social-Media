# %% [markdown]
# # Corpus YouTube

# %% [markdown]
# ## 1. Lectura de datos!

# %%
## abrimos los archivos

import glob

lista_files = glob.glob('YTessays/*.txt')
corpus = []

for file in lista_files:
    with open(file, 'r', encoding='utf8') as f:
        corpus+=[f.read()]

# %%
## número de textos

len(corpus)
# Out:
# 24

# %%
corpus[0][:250]
# Out:
# '("Faceshopping" by Sophie)\n♪ My face is the front of shop ♪\n♪ My face is the real shop front ♪\n♪ My shop is the face I front ♪\n♪ I\'m real when I shop my face ♪\n♪ Artificial bloom ♪\n♪ Hydroponic skin ♪\n♪ Chemical release ♪\n♪ Synthesize the real ♪\n(upb'

# %% [markdown]
# ## 2. Preprocesamiento de los datos

# %%
## librerias

import spacy
import nltk
import string
from nltk import sent_tokenize
import numpy as np
# Out:
# 2022-02-25 21:49:19.769085: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2022-02-25 21:49:19.769129: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /home/cerdamara/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
## función para remover () y []

def a(test_str):
    ret = ''
    skip1c = 0
    skip2c = 0
    for i in test_str:
        if i == '[':
            skip1c += 1
        elif i == '(':
            skip2c += 1
        elif i == ']' and skip1c > 0:
            skip1c -= 1
        elif i == ')'and skip2c > 0:
            skip2c -= 1
        elif skip1c == 0 and skip2c == 0:
            ret += i
    return ret

# %%
## aplicamos la función "a" a cada texto del corpus

corpus = [a(c) for c in corpus]

# %%
corpus[0][:250]
# Out:
# "\n♪ My face is the front of shop ♪\n♪ My face is the real shop front ♪\n♪ My shop is the face I front ♪\n♪ I'm real when I shop my face ♪\n♪ Artificial bloom ♪\n♪ Hydroponic skin ♪\n♪ Chemical release ♪\n♪ Synthesize the real ♪\n - Hey guys, it's Natalie,\nwel"

# %%
## dividimos por salto de linea cada texto

corpus = [c.replace('♪','').split('\n') for c in corpus]

# %%
corpus[0][:5]
# Out:
# ['',
#  ' My face is the front of shop ',
#  ' My face is the real shop front ',
#  ' My shop is the face I front ',
#  " I'm real when I shop my face "]

# %%
## eliminamos strings vacíos (cada texto)

corpus = [[sentence.strip() for sentence in c if len(sentence)>0] for c in corpus]

# %%
## volvemos a juntar las oraciones

corpus = [' '.join(c) for c in corpus]

# %%
corpus[0][:250]
# Out:
# "My face is the front of shop My face is the real shop front My shop is the face I front I'm real when I shop my face Artificial bloom Hydroponic skin Chemical release Synthesize the real - Hey guys, it's Natalie, welcome back to my channel. Today I'm"

# %%
## dividimos en oraciones cada texto

sentence_list = []

for texto in corpus:
    sentences = sent_tokenize(texto)
    sentence_list+=[sentences]

# %%
len(sentence_list)
# Out:
# 24

# %%
sentence_list[0][:5]
# Out:
# ["My face is the front of shop My face is the real shop front My shop is the face I front I'm real when I shop my face Artificial bloom Hydroponic skin Chemical release Synthesize the real - Hey guys, it's Natalie, welcome back to my channel.",
#  "Today I'm gonna do a makeup tutorial, as always, but first, story time, story time, story time!",
#  "I just wanna be upfront with you guys and let you know that I've had some facial surgery.",
#  "I'm always gonna be honest with you guys about this kind of thing because you mean so much to me.",
#  "Like you've been here with me since the beginning, and you've seen my story, my whole entire journey, this journey I've been on as a transgender woman."]

# %%
## filtramos por textos con al menos 2 oraciones

sentence_list = [s for s in sentence_list if len(s)>1]

# %%
len(sentence_list)
# Out:
# 23

# %%
#numero de oraciones por texto

numero_oraciones = sum([len(s) for s in sentence_list])
promedio_oraciones_por_texto = np.mean([len(s) for s in sentence_list])

# %%
numero_oraciones, promedio_oraciones_por_texto
# Out:
# (7355, 319.7826086956522)

# %%
## tokens y types

tokens = []

for texto in sentence_list:
    for sentence in texto:
        tokens+=sentence.split(' ')

tokens = [w.lower() for w in tokens]

# %%
## número de tokens y types en el corpus

len(tokens),len(set(tokens))
# Out:
# (142029, 17593)

# %%
# número de oraciones por texto
num_sen = [len(s) for s in sentence_list]
print(num_sen)
# Out:
# [322, 1041, 915, 73, 170, 128, 259, 264, 170, 333, 272, 367, 369, 424, 310, 425, 222, 317, 173, 318, 122, 201, 160]

# %% [markdown]
# ## análisis!

# %% [markdown]
# ### 1. Nominalizaciones
# El trabajo aquí es con listas de oraciones. Extraemos los sustantivos :)

# %%
# !pip install spacy
# !spacy download en
# Out:
# /usr/lib/python3/dist-packages/secretstorage/dhcrypto.py:15: CryptographyDeprecationWarning: int_from_bytes is deprecated, use int.from_bytes instead
#   from cryptography.utils import int_from_bytes
# /usr/lib/python3/dist-packages/secretstorage/util.py:19: CryptographyDeprecationWarning: int_from_bytes is deprecated, use int.from_bytes instead
#   from cryptography.utils import int_from_bytes
# Requirement already satisfied: spacy in /home/cerdamara/.local/lib/python3.8/site-packages (3.2.2)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.8 in /home/cerdamara/.local/lib/python3.8/site-packages (from spacy) (3.0.8)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /home/cerdamara/.local/lib/python3.8/site-packages (from spacy) (1.0.1)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /home/cerdamara/.local/lib/python3.8/site-packages (from spacy) (1.0.6)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /home/cerdamara/.local/lib/python3.8/site-packages (from spacy) (2.0.6)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /home/cerdamara/.local/lib/python3.8/site-packages (from spacy) (3.0.6)
# Requirement already satisfied: thinc<8.1.0,>=8.0.12 in /home/cerdamara/.local/lib/python3.8/site-packages (from spacy) (8.0.13)
# Requirement already satisfied: blis<0.8.0,>=0.4.0 in /home/cerdamara/.local/lib/python3.8/site-packages (from spacy) (0.7.5)
# Requirement already satisfied: wasabi<1.1.0,>=0.8.1 in /home/cerdamara/.local/lib/python3.8/site-packages (from spacy) (0.9.0)
# Requirement already satisfied: srsly<3.0.0,>=2.4.1 in /home/cerdamara/.local/lib/python3.8/site-packages (from spacy) (2.4.2)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /home/cerdamara/.local/lib/python3.8/site-packages (from spacy) (2.0.6)
# Requirement already satisfied: typer<0.5.0,>=0.3.0 in /home/cerdamara/.local/lib/python3.8/site-packages (from spacy) (0.3.2)
# Requirement already satisfied: pathy>=0.3.5 in /home/cerdamara/.local/lib/python3.8/site-packages (from spacy) (0.6.1)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /home/cerdamara/.local/lib/python3.8/site-packages (from spacy) (4.62.3)
# Requirement already satisfied: numpy>=1.15.0 in /home/cerdamara/.local/lib/python3.8/site-packages (from spacy) (1.22.2)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /home/cerdamara/.local/lib/python3.8/site-packages (from spacy) (2.22.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4 in /home/cerdamara/.local/lib/python3.8/site-packages (from spacy) (1.8.2)
# Requirement already satisfied: jinja2 in /home/cerdamara/.local/lib/python3.8/site-packages (from spacy) (3.0.3)
# Requirement already satisfied: setuptools in /home/cerdamara/.local/lib/python3.8/site-packages (from spacy) (60.9.3)
# Requirement already satisfied: packaging>=20.0 in /home/cerdamara/.local/lib/python3.8/site-packages (from spacy) (20.9)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /home/cerdamara/.local/lib/python3.8/site-packages (from spacy) (3.3.0)
# Requirement already satisfied: click<7.2.0,>=7.1.1 in /home/cerdamara/.local/lib/python3.8/site-packages (from typer<0.5.0,>=0.3.0->spacy) (7.1.2)
# Requirement already satisfied: smart-open<6.0.0,>=5.0.0 in /home/cerdamara/.local/lib/python3.8/site-packages (from pathy>=0.3.5->spacy) (5.2.1)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /home/cerdamara/.local/lib/python3.8/site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.0.4)
# Requirement already satisfied: idna<2.9,>=2.5 in /home/cerdamara/.local/lib/python3.8/site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.8)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /home/cerdamara/.local/lib/python3.8/site-packages (from requests<3.0.0,>=2.13.0->spacy) (1.25.11)
# Requirement already satisfied: certifi>=2017.4.17 in /home/cerdamara/.local/lib/python3.8/site-packages (from requests<3.0.0,>=2.13.0->spacy) (2021.10.8)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /home/cerdamara/.local/lib/python3.8/site-packages (from pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4->spacy) (3.10.0.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/cerdamara/.local/lib/python3.8/site-packages (from jinja2->spacy) (2.1.0)
# Requirement already satisfied: pyparsing>=2.0.2 in /home/cerdamara/.local/lib/python3.8/site-packages (from packaging>=20.0->spacy) (3.0.7)
# 2022-02-25 21:49:35.526380: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2022-02-25 21:49:35.526436: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# ⚠ As of spaCy v3.0, shortcuts like 'en' are deprecated. Please use the
# full pipeline package name 'en_core_web_sm' instead.
# /usr/lib/python3/dist-packages/secretstorage/dhcrypto.py:15: CryptographyDeprecationWarning: int_from_bytes is deprecated, use int.from_bytes instead
#   from cryptography.utils import int_from_bytes
# /usr/lib/python3/dist-packages/secretstorage/util.py:19: CryptographyDeprecationWarning: int_from_bytes is deprecated, use int.from_bytes instead
#   from cryptography.utils import int_from_bytes
# Requirement already satisfied: en-core-web-sm==3.2.0 from https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.2.0/en_core_web_sm-3.2.0-py3-none-any.whl#egg=en_core_web_sm==3.2.0 in /home/cerdamara/.local/lib/python3.8/site-packages (3.2.0)
# Requirement already satisfied: spacy<3.3.0,>=3.2.0 in /home/cerdamara/.local/lib/python3.8/site-packages (from en-core-web-sm==3.2.0) (3.2.2)
# Requirement already satisfied: blis<0.8.0,>=0.4.0 in /home/cerdamara/.local/lib/python3.8/site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (0.7.5)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /home/cerdamara/.local/lib/python3.8/site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (3.3.0)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /home/cerdamara/.local/lib/python3.8/site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (1.0.1)
# Requirement already satisfied: thinc<8.1.0,>=8.0.12 in /home/cerdamara/.local/lib/python3.8/site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (8.0.13)
# Requirement already satisfied: numpy>=1.15.0 in /home/cerdamara/.local/lib/python3.8/site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (1.22.2)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4 in /home/cerdamara/.local/lib/python3.8/site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (1.8.2)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /home/cerdamara/.local/lib/python3.8/site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (2.0.6)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.8 in /home/cerdamara/.local/lib/python3.8/site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (3.0.8)
# Requirement already satisfied: setuptools in /home/cerdamara/.local/lib/python3.8/site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (60.9.3)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /home/cerdamara/.local/lib/python3.8/site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (2.0.6)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /home/cerdamara/.local/lib/python3.8/site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (1.0.6)
# Requirement already satisfied: pathy>=0.3.5 in /home/cerdamara/.local/lib/python3.8/site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (0.6.1)
# Requirement already satisfied: jinja2 in /home/cerdamara/.local/lib/python3.8/site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (3.0.3)
# Requirement already satisfied: packaging>=20.0 in /home/cerdamara/.local/lib/python3.8/site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (20.9)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /home/cerdamara/.local/lib/python3.8/site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (4.62.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.1 in /home/cerdamara/.local/lib/python3.8/site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (2.4.2)
# Requirement already satisfied: wasabi<1.1.0,>=0.8.1 in /home/cerdamara/.local/lib/python3.8/site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (0.9.0)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /home/cerdamara/.local/lib/python3.8/site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (3.0.6)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /home/cerdamara/.local/lib/python3.8/site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (2.22.0)
# Requirement already satisfied: typer<0.5.0,>=0.3.0 in /home/cerdamara/.local/lib/python3.8/site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (0.3.2)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /home/cerdamara/.local/lib/python3.8/site-packages (from pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4->spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (3.10.0.2)
# Requirement already satisfied: smart-open<6.0.0,>=5.0.0 in /home/cerdamara/.local/lib/python3.8/site-packages (from pathy>=0.3.5->spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (5.2.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/cerdamara/.local/lib/python3.8/site-packages (from jinja2->spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (2.1.0)
# Requirement already satisfied: pyparsing>=2.0.2 in /home/cerdamara/.local/lib/python3.8/site-packages (from packaging>=20.0->spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (3.0.7)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /home/cerdamara/.local/lib/python3.8/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (3.0.4)
# Requirement already satisfied: idna<2.9,>=2.5 in /home/cerdamara/.local/lib/python3.8/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (2.8)
# Requirement already satisfied: certifi>=2017.4.17 in /home/cerdamara/.local/lib/python3.8/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (2021.10.8)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /home/cerdamara/.local/lib/python3.8/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (1.25.11)
# Requirement already satisfied: click<7.2.0,>=7.1.1 in /home/cerdamara/.local/lib/python3.8/site-packages (from typer<0.5.0,>=0.3.0->spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (7.1.2)
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')

# %%
oraciones_nlp = []

# %%
## identificamos el lema y el pos

import spacy
nlp = spacy.load("en_core_web_sm")

for sentence_text in sentence_list:
    if len(sentence_text)>1:
        sent = []
        for sentence in sentence_text:
            doc = nlp(sentence)
            sent += [(token.lemma_.lower(),token.pos_) for token in doc]
        oraciones_nlp += [sent]

# %%
len(oraciones_nlp)
# Out:
# 23

# %%
def number_tokens_types(oraciones):
    number=[pair[0] for pair in oraciones]
    return len(number),len(set(number)),len(set(number))/len(number)*100

# %%
## número de tokens y types para los 23 textos 

for oraciones in oraciones_nlp:
    print(number_tokens_types(oraciones))
# Out:
# (6448, 1297, 20.114764267990072)
# (20874, 2296, 10.999329309188465)
# (16843, 2280, 13.536780858516892)
# (2089, 422, 20.20105313547152)
# (2998, 526, 17.545030020013343)
# (2792, 572, 20.487106017191977)
# (8217, 1491, 18.14530850675429)
# (7271, 1246, 17.136569935359645)
# (3523, 653, 18.53533919954584)
# (6488, 1249, 19.250924784217016)
# (5241, 1010, 19.27113146346117)
# (8595, 1502, 17.475276323443865)
# (8649, 1442, 16.672447681812926)
# (8296, 1247, 15.031340405014465)
# (7519, 1529, 20.335150950924323)
# (10654, 1479, 13.882110005631688)
# (6639, 1079, 16.252447657779786)
# (9705, 1426, 14.693456980937661)
# (3206, 794, 24.76606363069245)
# (8006, 1025, 12.802897826630028)
# (4441, 860, 19.36500788110786)
# (4947, 920, 18.597129573478878)
# (3566, 834, 23.38754907459338)

# %%
def number_nouns(oraciones):
    number = [pair for pair in oraciones if pair[1]=='NOUN']
    return len(number)

# %%
## número de nouns tokens para los 23 textos 

for oraciones in oraciones_nlp:
    print(number_nouns(oraciones))
# Out:
# 1031
# 2832
# 2727
# 320
# 381
# 383
# 1282
# 1077
# 433
# 956
# 804
# 1283
# 1375
# 1469
# 1511
# 1711
# 1075
# 1522
# 508
# 947
# 627
# 573
# 478

# %%
## la pregunta es: ¿De este número de nouns cuántos son nominalizaciones?

# %%
## reglas de nominalization

## reglas de nominalization

no_nom = ['thing', 'things', 'somethings', 'something', 'anything', 'everything', 'nothing','original', 'special', 'normal', 'version', 'tutorial', 'moment', 'comment', 'criminal', 'morning', 'tradition', 'notification','question', 'element', 'quality']
terminacion = ['ment','ments','tions', 'tion','sions', 'sion', 'ibility','ibilities', 'ity','ities', 'ness','nesses', 'al','als','ings', 'ing']

# %%
def nominalization(oraciones):
    nom = []
    for pair in oraciones:
        if pair[0] not in no_nom:
            if pair[1]=='NOUN':
                for END in terminacion:
                    if pair[0].endswith(END):
                        nom+=[pair[0]]
    return nom

# %%
nom_list = []

for oraciones in oraciones_nlp:
    nom_list += [nominalization(oraciones)]

# %%
nom_list[0]
# Out:
# ['beginning',
#  'feminization',
#  'feminization',
#  'contouring',
#  'contouring',
#  'incision',
#  'fragment',
#  'incision',
#  'reconstruction',
#  'incision',
#  'anticipation',
#  'encouragement',
#  'jackal',
#  'vanity',
#  'feminization',
#  'reassignment',
#  'identity',
#  'argument',
#  'reality',
#  'ideal',
#  'transition',
#  'removal',
#  'grooming',
#  'thinking',
#  'realness',
#  'painting',
#  'femininity',
#  'aspiration',
#  'aging',
#  'intensity',
#  'artificial',
#  'skinmaxing',
#  'business',
#  'discussion',
#  'masculinization',
#  'looksmaxing',
#  'deal',
#  'arousal',
#  'evolution',
#  'contouring',
#  'ingenuity',
#  'resourcefulness',
#  'individuality',
#  'femininity',
#  'exploitation',
#  'bartering',
#  'judgment',
#  'exaggeration',
#  'delusion',
#  'embellishment',
#  'darkness',
#  'invention',
#  'darkness',
#  'aging',
#  'ritual',
#  'cleansing',
#  'corporation',
#  'kindness',
#  'saving',
#  'collection',
#  'facial',
#  'futility',
#  'solution',
#  'spiral',
#  'obsession',
#  'advertising',
#  'relation',
#  'awareness',
#  'contemplation',
#  'revolution',
#  'revolution',
#  'revolution',
#  'futility',
#  'representation',
#  'celebrity',
#  'spiral',
#  'ideal',
#  'originality',
#  'appreciation',
#  'superiority',
#  'solution',
#  'audacity',
#  'kindness']

# %%
num_nom_list = []

for oraciones in oraciones_nlp:
    num_nom_list += [len(nominalization(oraciones)), len(nominalization(oraciones))/number_nouns(oraciones)*100]

# %%
## porcentaje de nominalizaciones con respecto al total de tokens sustantivos para cada texto

num_nom_list
# Out:
# [83,
#  8.050436469447138,
#  366,
#  12.923728813559322,
#  326,
#  11.954528786211954,
#  38,
#  11.875,
#  34,
#  8.923884514435695,
#  26,
#  6.7885117493472595,
#  148,
#  11.54446177847114,
#  83,
#  7.706592386258125,
#  37,
#  8.545034642032332,
#  113,
#  11.820083682008368,
#  76,
#  9.45273631840796,
#  131,
#  10.210444271239282,
#  135,
#  9.818181818181818,
#  234,
#  15.929203539823009,
#  250,
#  16.545334215751158,
#  168,
#  9.818819403857393,
#  96,
#  8.930232558139535,
#  126,
#  8.278580814717477,
#  62,
#  12.204724409448819,
#  102,
#  10.770855332629356,
#  83,
#  13.237639553429027,
#  75,
#  13.089005235602095,
#  40,
#  8.368200836820083]

# %% [markdown]
# ## 2. Academic World List

# %%
#abriendo la lista de palabras academicas
with open('AcademicWordList.txt') as f:
    AWL=f.read()

# %%
#dividir por salto de linea
AWL= AWL.split('\n')

# %%
##eliminar espacios en blanco
AWL = [palabra.split(' ') for palabra in AWL if len(palabra)>0]
AWL = [item for sublist in AWL for item in sublist]

# %%
AWL.remove('-')
AWL.remove('comments')

# %%
texto = list(zip(*oraciones_nlp[0]))[0]

# %%
texto[:10]
# Out:
# ('my', 'face', 'be', 'the', 'front', 'of', 'shop', 'my', 'face', 'be')

# %%
len(tokens)
# Out:
# 142029

# %%
# función separadora de academic words
def academic(tokens):
    aca_list=[]
    for word in tokens:
        if word in AWL:
            aca_list+=[word]
    return aca_list

# %%
oraciones_nlp[0][:10]
# Out:
# [('my', 'PRON'),
#  ('face', 'NOUN'),
#  ('be', 'AUX'),
#  ('the', 'DET'),
#  ('front', 'NOUN'),
#  ('of', 'ADP'),
#  ('shop', 'NOUN'),
#  ('my', 'PRON'),
#  ('face', 'NOUN'),
#  ('be', 'AUX')]

# %%
oraciones_nlp[:10]
# Out:
# [[('my', 'PRON'),
#   ('face', 'NOUN'),
#   ('be', 'AUX'),
#   ('the', 'DET'),
#   ('front', 'NOUN'),
#   ('of', 'ADP'),
#   ('shop', 'NOUN'),
#   ('my', 'PRON'),
#   ('face', 'NOUN'),
#   ('be', 'AUX'),
#   ('the', 'DET'),
#   ('real', 'ADJ'),
#   ('shop', 'NOUN'),
#   ('front', 'NOUN'),
#   ('my', 'PRON'),
#   ('shop', 'NOUN'),
#   ('be', 'AUX'),
#   ('the', 'DET'),
#   ('face', 'NOUN'),
#   ('i', 'PRON'),
#   ('front', 'VERB'),
#   ('i', 'PRON'),
#   ('be', 'AUX'),
#   ('real', 'ADJ'),
#   ('when', 'SCONJ'),
#   ('i', 'PRON'),
#   ('shop', 'VERB'),
#   ('my', 'PRON'),
#   ('face', 'NOUN'),
#   ('artificial', 'PROPN'),
#   ('bloom', 'NOUN'),
#   ('hydroponic', 'ADJ'),
#   ('skin', 'NOUN'),
#   ('chemical', 'PROPN'),
#   ('release', 'NOUN'),
#   ('synthesize', 'PROPN'),
#   ('the', 'DET'),
#   ('real', 'ADJ'),
#   ('-', 'PUNCT'),
#   ('hey', 'ADJ'),
#   ('guy', 'NOUN'),
#   (',', 'PUNCT'),
#   ('it', 'PRON'),
#   ('be', 'AUX'),
#   ('natalie', 'PROPN'),
#   (',', 'PUNCT'),
#   ('welcome', 'VERB'),
#   ('back', 'ADP'),
#   ('to', 'ADP'),
#   ('my', 'PRON'),
#   ('channel', 'NOUN'),
#   ('.', 'PUNCT'),
#   ('today', 'NOUN'),
#   ('i', 'PRON'),
#   ('be', 'AUX'),
#   ('going', 'VERB'),
#   ('to', 'PART'),
#   ('do', 'VERB'),
#   ('a', 'DET'),
#   ('makeup', 'NOUN'),
#   ('tutorial', 'NOUN'),
#   (',', 'PUNCT'),
#   ('as', 'ADP'),
#   ('always', 'ADV'),
#   (',', 'PUNCT'),
#   ('but', 'CCONJ'),
#   ('first', 'ADV'),
#   (',', 'PUNCT'),
#   ('story', 'NOUN'),
#   ('time', 'NOUN'),
#   (',', 'PUNCT'),
#   ('story', 'NOUN'),
#   ('time', 'NOUN'),
#   (',', 'PUNCT'),
#   ('story', 'NOUN'),
#   ('time', 'NOUN'),
#   ('!', 'PUNCT'),
#   ('i', 'PRON'),
#   ('just', 'ADV'),
#   ('wanna', 'VERB'),
#   ('be', 'AUX'),
#   ('upfront', 'ADJ'),
#   ('with', 'ADP'),
#   ('you', 'PRON'),
#   ('guy', 'NOUN'),
#   ('and', 'CCONJ'),
#   ('let', 'VERB'),
#   ('you', 'PRON'),
#   ('know', 'VERB'),
#   ('that', 'SCONJ'),
#   ('i', 'PRON'),
#   ("'ve", 'AUX'),
#   ('have', 'VERB'),
#   ('some', 'DET'),
#   ('facial', 'ADJ'),
#   ('surgery', 'NOUN'),
#   ('.', 'PUNCT'),
#   ('i', 'PRON'),
#   ('be', 'AUX'),
#   ('always', 'ADV'),
#   ('going', 'VERB'),
#   ('to', 'PART'),
#   ('be', 'AUX'),
#   ('honest', 'ADJ'),
#   ('with', 'ADP'),
#   ('you', 'PRON'),
#   ('guy', 'NOUN'),
#   ('about', 'ADP'),
#   ('this', 'DET'),
#   ('kind', 'NOUN'),
#   ('of', 'ADP'),
#   ('thing', 'NOUN'),
#   ('because', 'SCONJ'),
#   ('you', 'PRON'),
#   ('mean', 'VERB'),
#   ('so', 'ADV'),
#   ('much', 'ADJ'),
#   ('to', 'ADP'),
#   ('i', 'PRON'),
#   ('.', 'PUNCT'),
#   ('like', 'SCONJ'),
#   ('you', 'PRON'),
#   ("'ve", 'AUX'),
#   ('be', 'AUX'),
#   ('here', 'ADV'),
#   ('with', 'ADP'),
#   ('i', 'PRON'),
#   ('since', 'SCONJ'),
#   ('the', 'DET'),
#   ('beginning', 'NOUN'),
#   (',', 'PUNCT'),
#   ('and', 'CCONJ'),
#   ('you', 'PRON'),
#   ("'ve", 'AUX'),
#   ('see', 'VERB'),
#   ('my', 'PRON'),
#   ('story', 'NOUN'),
#   (',', 'PUNCT'),
#   ('my', 'PRON'),
#   ('whole', 'ADJ'),
#   ('entire', 'ADJ'),
#   ('journey', 'NOUN'),
#   (',', 'PUNCT'),
#   ('this', 'DET'),
#   ('journey', 'NOUN'),
#   ('i', 'PRON'),
#   ("'ve", 'AUX'),
#   ('be', 'AUX'),
#   ('on', 'ADP'),
#   ('as', 'ADP'),
#   ('a', 'DET'),
#   ('transgender', 'NOUN'),
#   ('woman', 'NOUN'),
#   ('.', 'PUNCT'),
#   ('you', 'PRON'),
#   ("'ve", 'AUX'),
#   ('be', 'AUX'),
#   ('with', 'ADP'),
#   ('i', 'PRON'),
#   ('on', 'ADP'),
#   ('this', 'DET'),
#   ('whole', 'ADJ'),
#   ('journey', 'NOUN'),
#   ('.', 'PUNCT'),
#   ('this', 'PRON'),
#   ('be', 'AUX'),
#   ('my', 'PRON'),
#   ('truth', 'NOUN'),
#   (',', 'PUNCT'),
#   ('and', 'CCONJ'),
#   ('you', 'PRON'),
#   ("'ve", 'AUX'),
#   ('accept', 'VERB'),
#   ('the', 'DET'),
#   ('truth', 'NOUN'),
#   ('of', 'ADP'),
#   ('my', 'PRON'),
#   ('journey', 'NOUN'),
#   ('.', 'PUNCT'),
#   ('this', 'PRON'),
#   ('be', 'AUX'),
#   ('a', 'DET'),
#   ('really', 'ADV'),
#   ('vulnerable', 'ADJ'),
#   ('moment', 'NOUN'),
#   ('for', 'ADP'),
#   ('i', 'PRON'),
#   (',', 'PUNCT'),
#   ('and', 'CCONJ'),
#   ('you', 'PRON'),
#   ('guy', 'NOUN'),
#   ('be', 'AUX'),
#   ('just', 'ADV'),
#   ('so', 'ADV'),
#   ('special', 'ADJ'),
#   ('because', 'SCONJ'),
#   ('you', 'PRON'),
#   ("'ve", 'AUX'),
#   ('be', 'AUX'),
#   ('here', 'ADV'),
#   ('for', 'ADP'),
#   ('i', 'PRON'),
#   ('throughout', 'ADP'),
#   ('my', 'PRON'),
#   ('whole', 'ADJ'),
#   ('transgender', 'NOUN'),
#   ('journey', 'NOUN'),
#   ('.', 'PUNCT'),
#   ('the', 'DET'),
#   ('whole', 'ADJ'),
#   ('message', 'NOUN'),
#   ('of', 'ADP'),
#   ('my', 'PRON'),
#   ('journey', 'NOUN'),
#   ('as', 'ADP'),
#   ('an', 'DET'),
#   ('influencer', 'NOUN'),
#   ('ah', 'INTJ'),
#   ('!', 'PUNCT'),
#   ('of', 'ADP'),
#   ('the', 'DET'),
#   ('live', 'VERB'),
#   ('experience', 'NOUN'),
#   ('of', 'ADP'),
#   ('my', 'PRON'),
#   ('transgender', 'NOUN'),
#   ('journey', 'NOUN'),
#   ('as', 'ADP'),
#   ('a', 'DET'),
#   ('youtube', 'PROPN'),
#   ('influencer', 'NOUN'),
#   ('and', 'CCONJ'),
#   ('it', 'PRON'),
#   ('be', 'AUX'),
#   ('be', 'AUX'),
#   ('so', 'ADV'),
#   ('meaningful', 'ADJ'),
#   (',', 'PUNCT'),
#   ('and', 'CCONJ'),
#   ('i', 'PRON'),
#   ('be', 'AUX'),
#   ('go', 'VERB'),
#   ('a', 'DET'),
#   ('really', 'ADV'),
#   ('vulnerable', 'ADJ'),
#   ('time', 'NOUN'),
#   ('for', 'ADP'),
#   ('i', 'PRON'),
#   (',', 'PUNCT'),
#   ('and', 'CCONJ'),
#   ('i', 'PRON'),
#   ("'ve", 'AUX'),
#   ('be', 'AUX'),
#   ('so', 'ADV'),
#   ('grateful', 'ADJ'),
#   ('to', 'ADP'),
#   ('you', 'PRON'),
#   ('guy', 'NOUN'),
#   ('i', 'PRON'),
#   ('think', 'VERB'),
#   ('the', 'DET'),
#   ('main', 'ADJ'),
#   ('thing', 'NOUN'),
#   ('we', 'PRON'),
#   ("'ve", 'AUX'),
#   ('learn', 'VERB'),
#   ('together', 'ADV'),
#   ('on', 'ADP'),
#   ('this', 'DET'),
#   ('channel', 'NOUN'),
#   ('be', 'AUX'),
#   ('that', 'PRON'),
#   ('makeup', 'NOUN'),
#   ('be', 'AUX'),
#   ('a', 'DET'),
#   ('lot', 'NOUN'),
#   ('of', 'ADP'),
#   ('fun', 'NOUN'),
#   (',', 'PUNCT'),
#   ('but', 'CCONJ'),
#   ('it', 'PRON'),
#   ('be', 'AUX'),
#   ('inner', 'ADJ'),
#   ('beauty', 'NOUN'),
#   ('that', 'PRON'),
#   ('really', 'ADV'),
#   ('count', 'VERB'),
#   ('.', 'PUNCT'),
#   ('anyway', 'ADV'),
#   (',', 'PUNCT'),
#   ('let', 'VERB'),
#   ('us', 'PRON'),
#   ('talk', 'VERB'),
#   ('about', 'ADP'),
#   ('plastic', 'NOUN'),
#   ('surgery', 'NOUN'),
#   ('.', 'PUNCT'),
#   ('i', 'PRON'),
#   ('have', 'VERB'),
#   ('facial', 'ADJ'),
#   ('feminization', 'NOUN'),
#   ('surgery', 'NOUN'),
#   ('on', 'ADP'),
#   ('april', 'PROPN'),
#   ('2nd', 'NOUN'),
#   (',', 'PUNCT'),
#   ('so', 'CCONJ'),
#   ('about', 'ADV'),
#   ('a', 'PRON'),
#   ('month', 'NOUN'),
#   ('and', 'CCONJ'),
#   ('a', 'DET'),
#   ('half', 'NOUN'),
#   ('ago', 'ADV'),
#   ('.', 'PUNCT'),
#   ('what', 'PRON'),
#   ('we', 'PRON'),
#   ('call', 'VERB'),
#   ('facial', 'ADJ'),
#   ('feminization', 'NOUN'),
#   ('surgery', 'NOUN'),
#   (',', 'PUNCT'),
#   ('or', 'CCONJ'),
#   ('ffs', 'PROPN'),
#   (',', 'PUNCT'),
#   ('be', 'AUX'),
#   ('actually', 'ADV'),
#   ('a', 'DET'),
#   ('series', 'NOUN'),
#   ('of', 'ADP'),
#   ('different', 'ADJ'),
#   ('procedure', 'NOUN'),
#   ('that', 'PRON'),
#   ('some', 'DET'),
#   ('transgender', 'NOUN'),
#   ('woman', 'NOUN'),
#   ('choose', 'VERB'),
#   ('to', 'PART'),
#   ('have', 'VERB'),
#   ('to', 'PART'),
#   ('look', 'VERB'),
#   ('more', 'ADV'),
#   ('feminine', 'ADJ'),
#   ('.', 'PUNCT'),
#   ('so', 'ADV'),
#   ('what', 'PRON'),
#   ('i', 'PRON'),
#   ('have', 'AUX'),
#   ('do', 'VERB'),
#   ('be', 'AUX'),
#   ('forehead', 'ADJ'),
#   ('contouring', 'NOUN'),
#   (',', 'PUNCT'),
#   ('a', 'DET'),
#   ('brow', 'NOUN'),
#   ('lift', 'NOUN'),
#   (',', 'PUNCT'),
#   ('rhinoplasty', 'ADJ'),
#   (',', 'PUNCT'),
#   ('mandible', 'NOUN'),
#   ('contouring', 'NOUN'),
#   (',', 'PUNCT'),
#   ('a', 'DET'),
#   ('trachea', 'PROPN'),
#   ('shave', 'NOUN'),
#   ('.', 'PUNCT'),
#   ('you', 'PRON'),
#   ('know', 'VERB'),
#   (',', 'PUNCT'),
#   ('what', 'PRON'),
#   (',', 'PUNCT'),
#   ('let', 'VERB'),
#   ('us', 'PRON'),
#   ('just', 'ADV'),
#   ('have', 'VERB'),
#   ('the', 'DET'),
#   ('skull', 'PROPN'),
#   ('lady', 'NOUN'),
#   ('talk', 'NOUN'),
#   ('you', 'PRON'),
#   ('through', 'ADP'),
#   ('it', 'PRON'),
#   ('.', 'PUNCT'),
#   ('-', 'PUNCT'),
#   ('a', 'DET'),
#   ('coronal', 'ADJ'),
#   ('incision', 'NOUN'),
#   ('be', 'AUX'),
#   ('make', 'VERB'),
#   ('athwart', 'VERB'),
#   ('the', 'DET'),
#   ('cranial', 'ADJ'),
#   ('vault', 'NOUN'),
#   (',', 'PUNCT'),
#   ('whence', 'SCONJ'),
#   ('the', 'DET'),
#   ('skin', 'NOUN'),
#   ('of', 'ADP'),
#   ('the', 'DET'),
#   ('forehead', 'NOUN'),
#   ('be', 'AUX'),
#   ('strip', 'VERB'),
#   ('away', 'ADV'),
#   ('from', 'ADP'),
#   ('the', 'DET'),
#   ('bone', 'NOUN'),
#   ('.', 'PUNCT'),
#   ('a', 'DET'),
#   ('fragment', 'NOUN'),
#   ('of', 'ADP'),
#   ('the', 'DET'),
#   ('supraorbital', 'ADJ'),
#   ('ridge', 'NOUN'),
#   ('be', 'AUX'),
#   ('then', 'ADV'),
#   ('chisel', 'VERB'),
#   ('away', 'ADV'),
#   (',', 'PUNCT'),
#   ('remove', 'VERB'),
#   (',', 'PUNCT'),
#   ('reshape', 'VERB'),
#   (',', 'PUNCT'),
#   ('and', 'CCONJ'),
#   ('re', 'VERB'),
#   ('-', 'NOUN'),
#   ('affix', 'VERB'),
#   (',', 'PUNCT'),
#   ('thereby', 'ADV'),
#   ('eliminate', 'VERB'),
#   ('that', 'DET'),
#   ('undesirable', 'ADJ'),
#   ('prominence', 'NOUN'),
#   ('of', 'ADP'),
#   ('a', 'DET'),
#   ('robust', 'ADJ'),
#   ('brow', 'NOUN'),
#   ('that', 'PRON'),
#   ('ofttime', 'NOUN'),
#   ('distinguisheth', 'VERB'),
#   ('the', 'DET'),
#   ('skull', 'NOUN'),
#   ('of', 'ADP'),
#   ('the', 'DET'),
#   ('chad', 'PROPN'),
#   ('.', 'PUNCT'),
#   ('a', 'DET'),
#   ('second', 'ADJ'),
#   ('incision', 'NOUN'),
#   ('be', 'AUX'),
#   ('then', 'ADV'),
#   ('make', 'VERB'),
#   ('athwart', 'VERB'),
#   ('the', 'DET'),
#   ('columella', 'NOUN'),
#   ('of', 'ADP'),
#   ('the', 'DET'),
#   ('nasal', 'PROPN'),
#   ('septum', 'NOUN'),
#   (',', 'PUNCT'),
#   ('facilitate', 'VERB'),
#   ('a', 'DET'),
#   ('reconstruction', 'NOUN'),
#   ('of', 'ADP'),
#   ('the', 'DET'),
#   ('interior', 'ADJ'),
#   ('cartilage', 'NOUN'),
#   ('and', 'CCONJ'),
#   ('bone', 'NOUN'),
#   ('.', 'PUNCT'),
#   ('further', 'ADJ'),
#   ('incision', 'NOUN'),
#   ('be', 'AUX'),
#   ('make', 'VERB'),
#   ('betwixt', 'VERB'),
#   ('the', 'DET'),
#   ('gum', 'NOUN'),
#   ('and', 'CCONJ'),
#   ('cheek', 'VERB'),
#   (',', 'PUNCT'),
#   ('through', 'ADP'),
#   ('which', 'PRON'),
#   ('the', 'DET'),
#   ('mandible', 'NOUN'),
#   ('be', 'AUX'),
#   ('rasp', 'VERB'),
#   ('and', 'CCONJ'),
#   ('shave', 'VERB'),
#   ('down', 'ADP'),
#   ('to', 'ADP'),
#   ('a', 'DET'),
#   ('gracile', 'NOUN'),
#   ('curvature', 'NOUN'),
#   ('of', 'ADP'),
#   ('a', 'DET'),
#   ('jaw', 'NOUN'),
#   ('and', 'CCONJ'),
#   ('pointed', 'ADJ'),
#   ('chin', 'NOUN'),
#   (',', 'PUNCT'),
#   ('thereby', 'ADV'),
#   ('delineate', 'VERB'),
#   ('a', 'DET'),
#   ('facial', 'ADJ'),
#   ('silhouette', 'NOUN'),
#   ('exhibit', 'VERB'),
#   ('that', 'DET'),
#   ('aspect', 'NOUN'),
#   ('which', 'PRON'),
#   ('medical', 'ADJ'),
#   ('man', 'NOUN'),
#   ('call', 'VERB'),
#   ('cunty', 'ADJ'),
#   ('.', 'PUNCT'),
#   ('-', 'PUNCT'),
#   ('it', 'PRON'),
#   ('all', 'PRON'),
#   ('sound', 'VERB'),
#   ('pretty', 'ADV'),
#   ('gruesome', 'ADJ'),
#   ('when', 'SCONJ'),
#   ('you', 'PRON'),
#   ('describe', 'VERB'),
#   ('it', 'PRON'),
#   ('like', 'ADP'),
#   ('that', 'PRON'),
#   (',', 'PUNCT'),
#   ('but', 'CCONJ'),
#   ('there', 'PRON'),
#   ('be', 'VERB'),
#   ('actually', 'ADV'),
#   ('a', 'DET'),
#   ('very', 'ADV'),
#   ('fine', 'ADJ'),
#   ('level', 'NOUN'),
#   ('of', 'ADP'),
#   ('technique', 'NOUN'),
#   ('and', 'CCONJ'),
#   ('aesthetic', 'NOUN'),
#   ('involve', 'VERB'),
#   ('.', 'PUNCT'),
#   ('my', 'PRON'),
#   ('plastic', 'NOUN'),
#   ('surgeon', 'NOUN'),
#   ('be', 'AUX'),
#   ('an', 'DET'),
#   ('artist', 'NOUN'),
#   ('.', 'PUNCT'),
#   ('the', 'DET'),
#   ('result', 'NOUN'),
#   ('be', 'AUX'),
#   ('natural', 'ADJ'),
#   (',', 'PUNCT'),
#   ('i', 'PRON'),
#   ('do', 'AUX'),
#   ('not', 'PART'),
#   ('look', 'VERB'),
#   ('like', 'SCONJ'),
#   ('i', 'PRON'),
#   ("'ve", 'AUX'),
#   ('have', 'VERB'),
#   ('a', 'DET'),
#   ('bunch', 'NOUN'),
#   ('of', 'ADP'),
#   ('work', 'NOUN'),
#   ('do', 'VERB'),
#   (',', 'PUNCT'),
#   ('which', 'PRON'),
#   ('be', 'AUX'),
#   ('good', 'ADJ'),
#   ('.', 'PUNCT'),
#   ('you', 'PRON'),
#   ('know', 'VERB'),
#   (',', 'PUNCT'),
#   ('you', 'PRON'),
#   ('at', 'ADP'),
#   ('least', 'ADJ'),
#   ('wanna', 'PROPN'),
#   ('leave', 'VERB'),
#   ('people', 'NOUN'),
#   ('wonder', 'VERB'),
#   (',', 'PUNCT'),
#   ('maybe', 'ADV'),
#   ('she', 'PRON'),
#   ('be', 'AUX'),
#   ('bear', 'VERB'),
#   ('with', 'ADP'),
#   ('it', 'PRON'),
#   (',', 'PUNCT'),
#   ('maybe', 'ADV'),
#   ('a', 'DET'),
#   ('surgeon', 'NOUN'),
#   ('peel', 'VERB'),
#   ('her', 'PRON'),
#   ('face', 'NOUN'),
#   ('off', 'ADP'),
#   ('and', 'CCONJ'),
#   ('fix', 'VERB'),
#   ('her', 'PRON'),
#   ('shitty', 'ADJ'),
#   ('skull', 'NOUN'),
#   ('.', 'PUNCT'),
#   ('here', 'ADV'),
#   ('be', 'AUX'),
#   ('a', 'DET'),
#   ('before', 'NOUN'),
#   ('and', 'CCONJ'),
#   ('after', 'ADP'),
#   ('picture', 'NOUN'),
#   ('where', 'SCONJ'),
#   ('you', 'PRON'),
#   ('can', 'AUX'),
#   ('clearly', 'ADV'),
#   ('see', 'VERB'),
#   ('the', 'DET'),
#   ('difference', 'NOUN'),
#   (':', 'PUNCT'),
#   ('to', 'PART'),
#   ('use', 'VERB'),
#   ('the', 'DET'),
#   ('exact', 'ADJ'),
#   ('medical', 'ADJ'),
#   ('terminology', 'NOUN'),
#   (',', 'PUNCT'),
#   ('my', 'PRON'),
#   ('brow', 'NOUN'),
#   ('be', 'AUX'),
#   ('on', 'ADP'),
#   ('fleek', 'NOUN'),
#   (',', 'PUNCT'),
#   ('my', 'PRON'),
#   ('nose', 'NOUN'),
#   ('be', 'AUX'),
#   ('no', 'ADV'),
#   ('long', 'ADV'),
#   ('bust', 'VERB'),
#   ('the', 'DET'),
#   ('house', 'NOUN'),
#   (',', 'PUNCT'),
#   ('my', 'PRON'),
#   ('jaw', 'NOUN'),
#   ('be', 'AUX'),
#   ('snatch', 'VERB'),
#   (',', 'PUNCT'),
#   ('and', 'CCONJ'),
#   ('my', 'PRON'),
#   ('adam', 'PROPN'),
#   ("'s", 'PART'),
#   ('apple', 'NOUN'),
#   ('be', 'AUX'),
#   ('cancel', 'VERB'),
#   ('.', 'PUNCT'),
#   ('be', 'AUX'),
#   ('not', 'PART'),
#   ('it', 'PRON'),
#   ('always', 'ADV'),
#   ('really', 'ADV'),
#   ('eve', 'PROPN'),
#   ("'s", 'PART'),
#   ('apple', 'NOUN'),
#   ('?', 'PUNCT'),
#   ('maybe', 'ADV'),
#   ('satan', 'PROPN'),
#   ("'s", 'PART'),
#   ('apple', 'NOUN'),
#   ('.', 'PUNCT'),
#   ('i', 'PRON'),
#   ('think', 'VERB'),
#   ('i', 'PRON'),
#   ('still', 'ADV'),
#   ('look', 'VERB'),
#   ('like', 'ADP'),
#   ('myself', 'PRON'),
#   (',', 'PUNCT'),
#   ('it', 'PRON'),
#   ('be', 'AUX'),
#   ('not', 'PART'),
#   ('a', 'DET'),
#   ('new', 'ADJ'),
#   ('face', 'NOUN'),
#   ('.', 'PUNCT'),
#   ('we', 'PRON'),
#   ('be', 'AUX'),
#   ('talk', 'VERB'),
#   ('about', 'ADP'),
#   ('millimeter', 'NOUN'),
#   ('of', 'ADP'),
#   ('bone', 'NOUN'),
#   ('here', 'ADV'),
#   ('.', 'PUNCT'),
#   ('but', 'CCONJ'),
#   ('to', 'PART'),
#   ('have', 'VERB'),
#   ('all', 'PRON'),
#   ('that', 'PRON'),
#   ('do', 'VERB'),
#   ('be', 'AUX'),
#   (',', 'PUNCT'),
#   ('well', 'INTJ'),
#   (',', 'PUNCT'),
#   ('it', 'PRON'),
#   ('cost', 'VERB'),
#   ('a', 'DET'),
#   ('lot', 'NOUN'),
#   ('of', 'ADP'),
#   ('money', 'NOUN'),
#   (',', 'PUNCT'),
#   ('the', 'DET'),
#   ('anticipation', 'NOUN'),
#   ('be', 'AUX'),
#   (',', 'PUNCT'),
#   ('oh', 'INTJ'),
#   (',', 'PUNCT'),
#   ('terror', 'NOUN'),
#   ('like', 'SCONJ'),
#   ('i', 'PRON'),
#   ("'ve", 'AUX'),
#   ('never', 'ADV'),
#   ('know', 'VERB'),
#   (',', 'PUNCT'),
#   ('the', 'DET'),
#   ('pain', 'NOUN'),
#   ('be', 'AUX'),
#   ('memorable', 'ADJ'),
#   (',', 'PUNCT'),
#   ('and', 'CCONJ'),
#   ('the', 'DET'),
#   ('recovery', 'NOUN'),
#   ('take', 'VERB'),
#   ('more', 'ADJ'),
#   ('than', 'ADP'),
#   ('a', 'DET'),
#   ('month', 'NOUN'),
#   ('.', 'PUNCT'),
#   ('in', 'ADP'),
#   ('fact', 'NOUN'),
#   (',', 'PUNCT'),
#   ('i', 'PRON'),
#   ('still', 'ADV'),
#   ('have', 'VERB'),
#   ('some', 'DET'),
#   ('swell', 'VERB'),
#   ('in', 'ADP'),
#   ('my', 'PRON'),
#   ('jowl', 'NOUN'),
#   ('.', 'PUNCT'),
#   ('jowl', 'NOUN'),
#   (',', 'PUNCT'),
#   ('there', 'PRON'),
#   ('be', 'VERB'),
#   ('a', 'DET'),
#   ('nice', 'ADJ'),
#   ('feminine', 'NOUN'),
#   ('-', 'PUNCT'),
#   ('sound', 'VERB'),
#   ('word', 'NOUN'),
#   (',', 'PUNCT'),
#   ('love', 'VERB'),
#   ('that', 'PRON'),
#   ('.', 'PUNCT'),
#   ('the', 'DET'),
#   ('standard', 'ADJ'),
#   ('youtube', 'PROPN'),
#   ('t', 'PROPN'),
#   ('-', 'PUNCT'),
#   ('girl', 'NOUN'),
#   ('thing', 'NOUN'),
#   ('to', 'PART'),
#   ('do', 'VERB'),
#   ('of', 'ADP'),
#   ('course', 'NOUN'),
#   ('would', 'AUX'),
#   ('have', 'AUX'),
#   ('be', 'AUX'),
#   ('to', 'PART'),
#   ('vlog', 'VERB'),
#   ('the', 'DET'),
#   ('whole', 'ADJ'),
#   ('journey', 'NOUN'),
#   ('.', 'PUNCT'),
#   ('story', 'NOUN'),
#   ('time', 'NOUN'),
#   (',', 'PUNCT'),
#   ('my', 'PRON'),
#   ('facial', 'ADJ'),
#   ('surgery', 'NOUN'),
#   ('experience', 'NOUN'),
#   (',', 'PUNCT'),
#   ('my', 'PRON'),
#   ('ffs', 'PROPN'),
#   ('journey', 'NOUN'),
#   (',', 'PUNCT'),
#   ('and', 'CCONJ'),
#   ('post', 'VERB'),
#   ('constant', 'ADJ'),
#   ('social', 'ADJ'),
#   ('medium', 'NOUN'),
#   ('update', 'VERB'),
#   ('about', 'ADP'),
#   ('it', 'PRON'),
#   ('.', 'PUNCT'),
#   ('and', 'CCONJ'),
#   ('i', 'PRON'),
#   ('be', 'AUX'),
#   ('grateful', 'ADJ'),
#   ('to', 'ADP'),
#   ('the', 'DET'),
#   ('trans', 'PROPN'),
#   ('woman', 'NOUN'),
#   ('who', 'PRON'),
#   ('have', 'AUX'),
#   ('do', 'VERB'),
#   ('that', 'PRON'),
#   ('because', 'SCONJ'),
#   ('it', 'PRON'),
#   ('be', 'AUX'),
#   ('really', 'ADV'),
#   ('helpful', 'ADJ'),
#   ('to', 'ADP'),
#   ('i', 'PRON'),
#   ('to', 'PART'),
#   ('be', 'AUX'),
#   ('able', 'ADJ'),
#   ('to', 'PART'),
#   ('watch', 'VERB'),
#   ('those', 'DET'),
#   ('vlog', 'NOUN'),
#   ('in', 'ADP'),
#   ('advance', 'NOUN'),
#   ('and', 'CCONJ'),
#   ('know', 'VERB'),
#   ('what', 'PRON'),
#   ('i', 'PRON'),
#   ('be', 'AUX'),
#   ('get', 'VERB'),
#   ('myself', 'PRON'),
#   ('into', 'ADP'),
#   ('.', 'PUNCT'),
#   ('but', 'CCONJ'),
#   ('i', 'PRON'),
#   ('decide', 'VERB'),
#   ('not', 'PART'),
#   ('to', 'PART'),
#   ('post', 'VERB'),
#   ('about', 'ADP'),
#   ('the', 'DET'),
#   ('surgery', 'NOUN'),
#   ('because', 'SCONJ'),
#   ('i', 'PRON'),
#   ('want', 'VERB'),
#   ('privacy', 'NOUN'),
#   ('for', 'ADP'),
#   ('the', 'DET'),
#   ('recovery', 'NOUN'),
#   ('and', 'CCONJ'),
#   ('to', 'PART'),
#   ('just', 'ADV'),
#   ('take', 'VERB'),
#   ('some', 'DET'),
#   ('time', 'NOUN'),
#   ('to', 'PART'),
#   ('get', 'VERB'),
#   ('to', 'PART'),
#   ('feel', 'VERB'),
#   ('at', 'ADP'),
#   ('home', 'NOUN'),
#   ('with', 'ADP'),
#   ('the', 'DET'),
#   ('result', 'NOUN'),
#   ('before', 'ADP'),
#   ('subject', 'VERB'),
#   ('myself', 'PRON'),
#   ('to', 'ADP'),
#   ('the', 'DET'),
#   ('vicious', 'ADJ'),
#   ('thing', 'NOUN'),
#   ('they', 'PRON'),
#   ('say', 'VERB'),
#   ('about', 'ADP'),
#   ('i', 'PRON'),
#   ('in', 'ADP'),
#   ('the', 'DET'),
#   ('tabloid', 'NOUN'),
#   ('.', 'PUNCT'),
#   ('you', 'PRON'),
#   ('know', 'VERB'),
#   (',', 'PUNCT'),
#   ('i', 'PRON'),
#   ('think', 'VERB'),
#   ('i', 'PRON'),
#   ("'ve", 'AUX'),
#   ('be', 'AUX'),
#   ('kinda', 'ADV'),
#   ('psychologically', 'ADV'),
#   ('damage', 'VERB'),
#   ('by', 'ADP'),
#   ('read', 'VERB'),
#   ('for', 'ADP'),
#   ('year', 'NOUN'),
#   ('the', 'DET'),
#   ('thing', 'NOUN'),
#   ('people', 'NOUN'),
#   ('say', 'VERB'),
#   ('about', 'ADP'),
#   ('my', 'PRON'),
#   ('appearance', 'NOUN'),
#   ('online', 'ADV'),
#   ('.', 'PUNCT'),
#   ('and', 'CCONJ'),
#   ('i', 'PRON'),
#   ('be', 'AUX'),
#   ('not', 'PART'),
#   ('even', 'ADV'),
#   ('talk', 'VERB'),
#   ('about', 'ADP'),
#   ('the', 'DET'),
#   ('hater', 'NOUN'),
#   (',', 'PUNCT'),
#   ('like', 'ADP'),
#   ('at', 'ADP'),
#   ('this', 'DET'),
#   ('point', 'NOUN'),
#   ('i', 'PRON'),
#   ('can', 'AUX'),
#   ('mostly', 'ADV'),
#   ('brush', 'VERB'),
#   ('they', 'PRON'),
#   ('off', 'ADP'),
#   ('.', 'PUNCT'),
#   ('but', 'CCONJ'),
#   ('for', 'ADP'),
#   ('instance', 'NOUN'),
#   (',', 'PUNCT'),
#   ('about', 'ADV'),
#   ('a', 'PRON'),
#   ('year', 'NOUN'),
#   ('ago', 'ADV'),
#   (',', 'PUNCT'),
#   ('i', 'PRON'),
#   ('be', 'AUX'),
#   ('read', 'VERB'),
#   ('through', 'ADP'),
#   ('a', 'DET'),
#   ('transgender', 'NOUN'),
#   ('subreddit', 'NOUN'),
#   (',', 'PUNCT'),
#   ('and', 'CCONJ'),
#   ('some', 'DET'),
#   ('trans', 'PROPN'),
#   ('woman', 'NOUN'),
#   ('be', 'AUX'),
#   ('agonize', 'VERB'),
#   ('about', 'ADP'),
#   ('her', 'PRON'),
#   ('appearance', 'NOUN'),
#   (',', 'PUNCT'),
#   ('and', 'CCONJ'),
#   ('someone', 'PRON'),
#   ('offer', 'VERB'),
#   ('the', 'DET'),
#   ('encouragement', 'NOUN'),
#   (',', 'PUNCT'),
#   ('"', 'PUNCT'),
#   ('you', 'PRON'),
#   ('know', 'VERB'),
#   (',', 'PUNCT'),
#   ('"', 'PUNCT'),
#   ('you', 'PRON'),
#   ('can', 'AUX'),
#   ('still', 'ADV'),
#   ('look', 'VERB'),
#   ('hot', 'ADJ'),
#   ('even', 'ADV'),
#   ('if', 'SCONJ'),
#   ('you', 'PRON'),
#   ('do', 'AUX'),
#   ('not', 'PART'),
#   ('pass', 'VERB'),
#   (',', 'PUNCT'),
#   ('"', 'PUNCT'),
#   ('just', 'ADV'),
#   ('look', 'VERB'),
#   ('at', 'ADP'),
#   ('contrapoints', 'PROPN'),
#   ('.', 'PUNCT'),
#   ('"', 'PUNCT'),
#   ('ugh', 'INTJ'),
#   (',', 'PUNCT'),
#   ('like', 'ADP'),
#   ('a', 'DET'),
#   ('dagger', 'NOUN'),
#   ('to', 'ADP'),
#   ('the', 'DET'),
#   ('heart', 'NOUN'),
#   (',', 'PUNCT'),
#   ('the', 'DET'),
#   ('unintentional', 'ADJ'),
#   ('shade', 'NOUN'),
#   ('of', 'ADP'),
#   ('it', 'PRON'),
#   ('all', 'PRON'),
#   ...],
#  [('-', 'PUNCT'),
#   ('okay', 'INTJ'),
#   ('.', 'PUNCT'),
#   ('let', 'VERB'),
#   ('us', 'PRON'),
#   ('get', 'AUX'),
#   ('start', 'VERB'),
#   ('.', 'PUNCT'),
#   ('i', 'PRON'),
#   ('literally', 'ADV'),
#   ('need', 'VERB'),
#   ('a', 'DET'),
#   ('man', 'NOUN'),
#   ('.', 'PUNCT'),
#   ('i', 'PRON'),
#   ('need', 'VERB'),
#   ('a', 'DET'),
#   ('man', 'NOUN'),
#   (',', 'PUNCT'),
#   ('help', 'NOUN'),
#   ('!', 'PUNCT'),
#   ('all', 'ADV'),
#   ('right', 'ADV'),
#   (',', 'PUNCT'),
#   ('i', 'PRON'),
#   ('be', 'AUX'),
#   ('going', 'VERB'),
#   ('to', 'PART'),
#   ('get', 'VERB'),
#   ('plier', 'NOUN'),
#   (',', 'PUNCT'),
#   ('the', 'DET'),
#   ('lesbian', 'PROPN'),
#   ('solution', 'NOUN'),
#   ('.', 'PUNCT'),
#   ('okay', 'INTJ'),
#   ('.', 'PUNCT'),
#   ('let', 'VERB'),
#   ('us', 'PRON'),
#   ('get', 'AUX'),
#   ('start', 'VERB'),
#   ('.', 'PUNCT'),
#   ('i', 'PRON'),
#   ('love', 'VERB'),
#   ('my', 'PRON'),
#   ('king', 'NOUN'),
#   ('.', 'PUNCT'),
#   ('this', 'PRON'),
#   ('be', 'AUX'),
#   ('not', 'PART'),
#   ('really', 'ADV'),
#   ('the', 'DET'),
#   ('most', 'ADV'),
#   ('feminine', 'ADJ'),
#   ('moment', 'NOUN'),
#   ('for', 'ADP'),
#   ('i', 'PRON'),
#   (',', 'PUNCT'),
#   ('not', 'PART'),
#   ('really', 'ADV'),
#   ('my', 'PRON'),
#   ('2020', 'NUM'),
#   ('vibe', 'NOUN'),
#   ('.', 'PUNCT'),
#   ('but', 'CCONJ'),
#   ('it', 'PRON'),
#   ('do', 'AUX'),
#   ('proportionize', 'VERB'),
#   ('my', 'PRON'),
#   ('giant', 'ADJ'),
#   ('man', 'NOUN'),
#   ('hand', 'NOUN'),
#   ('.', 'PUNCT'),
#   ('nyew', 'ADJ'),
#   (',', 'PUNCT'),
#   ('nyew', 'ADJ'),
#   (',', 'PUNCT'),
#   ('nyew', 'ADJ'),
#   ('.', 'PUNCT'),
#   ('all', 'ADV'),
#   ('right', 'ADV'),
#   (',', 'PUNCT'),
#   ('no', 'DET'),
#   ('one', 'NOUN'),
#   ('think', 'VERB'),
#   ('i', 'PRON'),
#   ('be', 'AUX'),
#   ('cute', 'ADJ'),
#   (',', 'PUNCT'),
#   ('let', 'VERB'),
#   ('us', 'PRON'),
#   ('get', 'AUX'),
#   ('start', 'VERB'),
#   ('.', 'PUNCT'),
#   ('okay', 'INTJ'),
#   (',', 'PUNCT'),
#   ('look', 'VERB'),
#   (',', 'PUNCT'),
#   ('this', 'DET'),
#   ('video', 'NOUN'),
#   ('be', 'AUX'),
#   ('about', 'ADP'),
#   ('cancel', 'VERB'),
#   (',', 'PUNCT'),
#   ('also', 'ADV'),
#   ('know', 'VERB'),
#   ('as', 'ADP'),
#   ('cancel', 'NOUN'),
#   ('culture', 'NOUN'),
#   (',', 'PUNCT'),
#   ('formerly', 'ADV'),
#   ('know', 'VERB'),
#   ('as', 'ADP'),
#   ('call', 'NOUN'),
#   ('-', 'PUNCT'),
#   ('out', 'ADP'),
#   ('culture', 'NOUN'),
#   ('.', 'PUNCT'),
#   ('and', 'CCONJ'),
#   ('i', 'PRON'),
#   ('know', 'VERB'),
#   ('you', 'PRON'),
#   ('kid', 'NOUN'),
#   ('know', 'VERB'),
#   ('all', 'ADV'),
#   ('about', 'ADP'),
#   ('this', 'PRON'),
#   ('but', 'CCONJ'),
#   ('before', 'SCONJ'),
#   ('i', 'PRON'),
#   ('dive', 'VERB'),
#   ('in', 'ADV'),
#   (',', 'PUNCT'),
#   ('i', 'PRON'),
#   ('have', 'VERB'),
#   ('to', 'PART'),
#   ('explain', 'VERB'),
#   ('the', 'DET'),
#   ('basic', 'NOUN'),
#   ('to', 'ADP'),
#   ('my', 'PRON'),
#   ('fellow', 'ADJ'),
#   ('boomer', 'NOUN'),
#   ('.', 'PUNCT'),
#   ('so', 'ADV'),
#   ('listen', 'VERB'),
#   ('up', 'ADP'),
#   ('oldie', 'NOUN'),
#   (',', 'PUNCT'),
#   ('in', 'ADP'),
#   ('the', 'DET'),
#   ('lingo', 'NOUN'),
#   ('of', 'ADP'),
#   ('these', 'DET'),
#   ('young', 'ADJ'),
#   ('avocado', 'NOUN'),
#   ('-', 'PUNCT'),
#   ('guzzle', 'VERB'),
#   ('smartphone', 'ADJ'),
#   ('addict', 'NOUN'),
#   ('who', 'PRON'),
#   ('kill', 'VERB'),
#   ('applebee', 'PROPN'),
#   ("'s", 'PART'),
#   (',', 'PUNCT'),
#   ('cancel', 'VERB'),
#   ('be', 'AUX'),
#   ('online', 'ADV'),
#   ('shame', 'VERB'),
#   (',', 'PUNCT'),
#   ('vilify', 'VERB'),
#   ('and', 'CCONJ'),
#   ('ostracizing', 'NOUN'),
#   ('of', 'ADP'),
#   ('prominent', 'ADJ'),
#   ('member', 'NOUN'),
#   ('of', 'ADP'),
#   ('a', 'DET'),
#   ('community', 'NOUN'),
#   ('by', 'ADP'),
#   ('other', 'ADJ'),
#   ('member', 'NOUN'),
#   ('of', 'ADP'),
#   ('that', 'DET'),
#   ('community', 'NOUN'),
#   ('.', 'PUNCT'),
#   ('like', 'INTJ'),
#   ('so', 'ADV'),
#   ('much', 'ADJ'),
#   ('internet', 'NOUN'),
#   ('slang', 'NOUN'),
#   (',', 'PUNCT'),
#   ('this', 'DET'),
#   ('use', 'NOUN'),
#   ('of', 'ADP'),
#   ('the', 'DET'),
#   ('word', 'NOUN'),
#   ('cancel', 'VERB'),
#   ('start', 'VERB'),
#   ('out', 'ADP'),
#   ('on', 'ADP'),
#   ('black', 'ADJ'),
#   ('twitter', 'PROPN'),
#   ('where', 'SCONJ'),
#   ('a', 'DET'),
#   ('few', 'ADJ'),
#   ('year', 'NOUN'),
#   ('ago', 'ADV'),
#   ('people', 'NOUN'),
#   (',', 'PUNCT'),
#   ('well', 'ADV'),
#   (',', 'PUNCT'),
#   ('mostly', 'ADV'),
#   ('woman', 'NOUN'),
#   (',', 'PUNCT'),
#   ('would', 'AUX'),
#   ('tweet', 'VERB'),
#   ('"', 'PUNCT'),
#   ('cancel', 'VERB'),
#   ('r.', 'PROPN'),
#   ('kelly', 'PROPN'),
#   ('"', 'PUNCT'),
#   ('and', 'CCONJ'),
#   ('thing', 'NOUN'),
#   ('like', 'ADP'),
#   ('that', 'PRON'),
#   ('.', 'PUNCT'),
#   ('you', 'PRON'),
#   ('know', 'VERB'),
#   (',', 'PUNCT'),
#   ('it', 'PRON'),
#   ('start', 'VERB'),
#   ('out', 'ADP'),
#   ('as', 'ADP'),
#   ('this', 'DET'),
#   ('vigilante', 'ADJ'),
#   ('strategy', 'NOUN'),
#   ('for', 'ADP'),
#   ('bring', 'VERB'),
#   ('justice', 'NOUN'),
#   ('and', 'CCONJ'),
#   ('accountability', 'NOUN'),
#   ('to', 'ADP'),
#   ('powerful', 'ADJ'),
#   ('people', 'NOUN'),
#   ('who', 'PRON'),
#   ('previously', 'ADV'),
#   ('have', 'AUX'),
#   ('be', 'AUX'),
#   ('immune', 'ADJ'),
#   ('to', 'ADP'),
#   ('any', 'DET'),
#   ('consequence', 'NOUN'),
#   ('for', 'ADP'),
#   ('their', 'PRON'),
#   ('action', 'NOUN'),
#   ('.', 'PUNCT'),
#   ('for', 'ADP'),
#   ('example', 'NOUN'),
#   (',', 'PUNCT'),
#   ('the', 'DET'),
#   ('me', 'PROPN'),
#   ('too', 'ADJ'),
#   ('movement', 'NOUN'),
#   ('promise', 'VERB'),
#   ('to', 'PART'),
#   ('use', 'VERB'),
#   ('social', 'ADJ'),
#   ('medium', 'NOUN'),
#   ('shame', 'VERB'),
#   ('to', 'PART'),
#   ('topple', 'VERB'),
#   ('sexually', 'ADV'),
#   ('abusive', 'ADJ'),
#   ('man', 'NOUN'),
#   ('in', 'ADP'),
#   ('power', 'NOUN'),
#   ('who', 'PRON'),
#   ('could', 'AUX'),
#   ('not', 'PART'),
#   ('be', 'AUX'),
#   ('hold', 'VERB'),
#   ('accountable', 'ADJ'),
#   ('in', 'ADP'),
#   ('any', 'DET'),
#   ('other', 'ADJ'),
#   ('way', 'NOUN'),
#   ('.', 'PUNCT'),
#   ('the', 'DET'),
#   ('promise', 'NOUN'),
#   ('of', 'ADP'),
#   ('cancel', 'VERB'),
#   ('be', 'AUX'),
#   ('that', 'SCONJ'),
#   ('it', 'PRON'),
#   ('be', 'AUX'),
#   ('go', 'VERB'),
#   ('to', 'PART'),
#   ('give', 'VERB'),
#   ('power', 'NOUN'),
#   ('back', 'ADV'),
#   ('to', 'ADP'),
#   ('people', 'NOUN'),
#   ('who', 'PRON'),
#   ('have', 'VERB'),
#   ('none', 'NOUN'),
#   (',', 'PUNCT'),
#   ('and', 'CCONJ'),
#   ('bring', 'VERB'),
#   ('justice', 'NOUN'),
#   ('to', 'ADP'),
#   ('prominent', 'ADJ'),
#   ('abuser', 'NOUN'),
#   ('.', 'PUNCT'),
#   ('it', 'PRON'),
#   ('be', 'AUX'),
#   (',', 'PUNCT'),
#   ('in', 'ADP'),
#   ('a', 'DET'),
#   ('way', 'NOUN'),
#   (',', 'PUNCT'),
#   ('the', 'DET'),
#   ('21st', 'ADJ'),
#   ('century', 'NOUN'),
#   ('version', 'NOUN'),
#   ('of', 'ADP'),
#   ('the', 'DET'),
#   ('guillotine', 'NOUN'),
#   (',', 'PUNCT'),
#   ('the', 'DET'),
#   ('bringer', 'NOUN'),
#   ('of', 'ADP'),
#   ('justice', 'NOUN'),
#   (',', 'PUNCT'),
#   ('the', 'DET'),
#   ('people', 'NOUN'),
#   ("'s", 'PART'),
#   ('avenger', 'NOUN'),
#   ('.', 'PUNCT'),
#   ('but', 'CCONJ'),
#   (',', 'PUNCT'),
#   ('also', 'ADV'),
#   ('like', 'ADP'),
#   ('the', 'DET'),
#   ('guillotine', 'NOUN'),
#   (',', 'PUNCT'),
#   ('it', 'PRON'),
#   ('can', 'AUX'),
#   ('become', 'VERB'),
#   ('a', 'DET'),
#   ('sadistic', 'ADJ'),
#   ('entertainment', 'NOUN'),
#   ('spectacle', 'NOUN'),
#   ('.', 'PUNCT'),
#   ('and', 'CCONJ'),
#   ('i', 'PRON'),
#   ('wanna', 'VERB'),
#   ('make', 'VERB'),
#   ('the', 'DET'),
#   ('case', 'NOUN'),
#   ('that', 'SCONJ'),
#   ('we', 'PRON'),
#   ('do', 'AUX'),
#   ('have', 'VERB'),
#   (',', 'PUNCT'),
#   ('well', 'INTJ'),
#   (',', 'PUNCT'),
#   ('a', 'DET'),
#   ('teensy', 'NUM'),
#   ('bit', 'NOUN'),
#   ('of', 'ADP'),
#   ('a', 'DET'),
#   ('reign', 'PROPN'),
#   ('of', 'ADP'),
#   ('terror', 'PROPN'),
#   ('situation', 'NOUN'),
#   ('on', 'ADP'),
#   ('our', 'PRON'),
#   ('hand', 'NOUN'),
#   (',', 'PUNCT'),
#   ('gorg', 'PROPN'),
#   ('.', 'PUNCT'),
#   ('now', 'ADV'),
#   ('there', 'PRON'),
#   ('be', 'VERB'),
#   ('a', 'DET'),
#   ('version', 'NOUN'),
#   ('of', 'ADP'),
#   ('this', 'DET'),
#   ('conversation', 'NOUN'),
#   ('that', 'PRON'),
#   ('be', 'AUX'),
#   ('already', 'ADV'),
#   ('be', 'AUX'),
#   ('have', 'VERB'),
#   ('to', 'ADP'),
#   ('death', 'NOUN'),
#   (',', 'PUNCT'),
#   ('and', 'CCONJ'),
#   ('it', 'PRON'),
#   ('go', 'VERB'),
#   ('like', 'ADP'),
#   ('this', 'PRON'),
#   ('.', 'PUNCT'),
#   ('on', 'ADP'),
#   ('the', 'DET'),
#   ('one', 'NUM'),
#   ('side', 'NOUN'),
#   ('be', 'AUX'),
#   ('a', 'DET'),
#   ('bunch', 'NOUN'),
#   ('of', 'ADP'),
#   ('male', 'ADJ'),
#   ('comedian', 'NOUN'),
#   ('who', 'PRON'),
#   ('constantly', 'ADV'),
#   ('bitch', 'VERB'),
#   ('about', 'ADP'),
#   ('how', 'SCONJ'),
#   ('cancel', 'ADJ'),
#   ('culture', 'NOUN'),
#   ('be', 'AUX'),
#   ('out', 'ADP'),
#   ('of', 'ADP'),
#   ('control', 'NOUN'),
#   (',', 'PUNCT'),
#   ('you', 'PRON'),
#   ('can', 'AUX'),
#   ('not', 'PART'),
#   ('joke', 'VERB'),
#   ('about', 'ADP'),
#   ('anything', 'PRON'),
#   ('anymore', 'ADV'),
#   ('without', 'ADP'),
#   ('these', 'DET'),
#   ('millennial', 'ADJ'),
#   ('jackal', 'NOUN'),
#   ('try', 'VERB'),
#   ('to', 'PART'),
#   ('get', 'VERB'),
#   ('you', 'PRON'),
#   ('in', 'ADP'),
#   ('trouble', 'NOUN'),
#   ('.', 'PUNCT'),
#   ('and', 'CCONJ'),
#   ('the', 'DET'),
#   ('other', 'ADJ'),
#   ('side', 'NOUN'),
#   ('be', 'AUX'),
#   ('mostly', 'ADV'),
#   ('progressive', 'ADJ'),
#   ('think', 'NOUN'),
#   ('piece', 'NOUN'),
#   ('author', 'NOUN'),
#   ('who', 'PRON'),
#   ('argue', 'VERB'),
#   ('that', 'SCONJ'),
#   ('there', 'PRON'),
#   ('be', 'VERB'),
#   ('no', 'DET'),
#   ('such', 'ADJ'),
#   ('thing', 'NOUN'),
#   ('as', 'ADP'),
#   ('cancel', 'NOUN'),
#   ('culture', 'NOUN'),
#   (',', 'PUNCT'),
#   ('it', 'PRON'),
#   ('be', 'AUX'),
#   ('just', 'ADV'),
#   ('that', 'SCONJ'),
#   ('powerful', 'ADJ'),
#   ('people', 'NOUN'),
#   ('be', 'AUX'),
#   ('finally', 'ADV'),
#   ('be', 'AUX'),
#   ('hold', 'VERB'),
#   ('accountable', 'ADJ'),
#   ('for', 'ADP'),
#   ('their', 'PRON'),
#   ('action', 'NOUN'),
#   ('and', 'CCONJ'),
#   ('they', 'PRON'),
#   ('can', 'AUX'),
#   ('not', 'PART'),
#   ('f*cke', 'VERB'),
#   ('handle', 'VERB'),
#   ('it', 'PRON'),
#   ('so', 'SCONJ'),
#   ('they', 'PRON'),
#   ('go', 'VERB'),
#   ('around', 'ADV'),
#   ('bitch', 'VERB'),
#   ('about', 'ADP'),
#   ('cancel', 'NOUN'),
#   ('culture', 'NOUN'),
#   ('.', 'PUNCT'),
#   ('now', 'ADV'),
#   ('unfortunately', 'ADV'),
#   (',', 'PUNCT'),
#   ('neither', 'PRON'),
#   ('of', 'ADP'),
#   ('those', 'DET'),
#   ('viewpoint', 'NOUN'),
#   ('be', 'AUX'),
#   ('quite', 'ADV'),
#   ('as', 'ADV'),
#   ('correct', 'ADJ'),
#   ('as', 'SCONJ'),
#   ('some', 'DET'),
#   ('people', 'NOUN'),
#   ('might', 'AUX'),
#   ('hope', 'VERB'),
#   ('.', 'PUNCT'),
#   ('so', 'ADV'),
#   (',', 'PUNCT'),
#   ('it', 'PRON'),
#   ('be', 'AUX'),
#   ('a', 'DET'),
#   ('good', 'ADJ'),
#   ('thing', 'NOUN'),
#   ('i', 'PRON'),
#   ('be', 'AUX'),
#   ('here', 'ADV'),
#   ('to', 'PART'),
#   ('deliver', 'VERB'),
#   ('the', 'DET'),
#   ('truth', 'NOUN'),
#   ('.', 'PUNCT'),
#   ('he', 'PRON'),
#   ('do', 'AUX'),
#   ('not', 'PART'),
#   ('know', 'VERB'),
#   ('i', 'PRON'),
#   ('be', 'AUX'),
#   ('transgender', 'ADJ'),
#   ('.', 'PUNCT'),
#   ('story', 'NOUN'),
#   ('time', 'NOUN'),
#   (',', 'PUNCT'),
#   ('emotional', 'ADJ'),
#   (',', 'PUNCT'),
#   ('not', 'PART'),
#   ('click', 'VERB'),
#   ('bait', 'NOUN'),
#   ('.', 'PUNCT'),
#   ('let', 'VERB'),
#   ('us', 'PRON'),
#   ('start', 'VERB'),
#   ('with', 'ADP'),
#   ('an', 'DET'),
#   ('example', 'NOUN'),
#   ('.', 'PUNCT'),
#   ('the', 'DET'),
#   ('most', 'ADV'),
#   ('high', 'ADJ'),
#   ('-', 'PUNCT'),
#   ('profile', 'NOUN'),
#   ('youtube', 'PROPN'),
#   ('canceling', 'NOUN'),
#   ('of', 'ADP'),
#   ('2019', 'NUM'),
#   ('be', 'AUX'),
#   ('the', 'DET'),
#   ('canceling', 'NOUN'),
#   ('of', 'ADP'),
#   ('james', 'PROPN'),
#   ('charles', 'PROPN'),
#   ('.', 'PUNCT'),
#   ('and', 'CCONJ'),
#   ('again', 'ADV'),
#   (',', 'PUNCT'),
#   ('i', 'PRON'),
#   ('know', 'VERB'),
#   ('you', 'PRON'),
#   ('kid', 'NOUN'),
#   ('remember', 'VERB'),
#   ('this', 'PRON'),
#   (',', 'PUNCT'),
#   ('but', 'CCONJ'),
#   (' ', 'SPACE'),
#   ('i', 'PRON'),
#   ('have', 'VERB'),
#   ('to', 'PART'),
#   ('reheat', 'VERB'),
#   ('ancient', 'ADJ'),
#   ('youtube', 'PROPN'),
#   ('tea', 'NOUN'),
#   ('for', 'ADP'),
#   ('the', 'DET'),
#   ('elder', 'NOUN'),
#   ('.', 'PUNCT'),
#   ('put', 'VERB'),
#   ('the', 'DET'),
#   ('kettle', 'NOUN'),
#   ('on', 'ADP'),
#   (',', 'PUNCT'),
#   ('karen', 'PROPN'),
#   ('.', 'PUNCT'),
#   ('so', 'ADV'),
#   ('james', 'PROPN'),
#   ('charles', 'PROPN'),
#   ('be', 'AUX'),
#   ('a', 'DET'),
#   ('20', 'NUM'),
#   ('-', 'PUNCT'),
#   ('year', 'NOUN'),
#   ('-', 'PUNCT'),
#   ('old', 'ADJ'),
#   ('beauty', 'NOUN'),
#   ('guru', 'NOUN'),
#   (',', 'PUNCT'),
#   ('which', 'PRON'),
#   ('mean', 'VERB'),
#   (',', 'PUNCT'),
#   ('boomer', 'NOUN'),
#   (',', 'PUNCT'),
#   ('look', 'VERB'),
#   ('there', 'PRON'),
#   ('be', 'VERB'),
#   ('these', 'DET'),
#   ('people', 'NOUN'),
#   ('who', 'PRON'),
#   ('make', 'VERB'),
#   ('youtube', 'PROPN'),
#   ('video', 'NOUN'),
#   ('teach', 'VERB'),
#   ('you', 'PRON'),
#   ('how', 'SCONJ'),
#   ('to', 'PART'),
#   ('do', 'VERB'),
#   ('makeup', 'NOUN'),
#   ('.', 'PUNCT'),
#   ('it', 'PRON'),
#   ('be', 'AUX'),
#   ('worth', 'ADJ'),
#   ('check', 'VERB'),
#   ('out', 'ADP'),
#   ('if', 'SCONJ'),
#   ('you', 'PRON'),
#   ('can', 'AUX'),
#   ('figure', 'VERB'),
#   ('out', 'ADP'),
#   ('how', 'SCONJ'),
#   ('to', 'PART'),
#   ('start', 'VERB'),
#   ('up', 'ADP'),
#   ('internet', 'PROPN'),
#   ('explorer', 'PROPN'),
#   ('.', 'PUNCT'),
#   ('i', 'PRON'),
#   ('certainly', 'ADV'),
#   ('can', 'AUX'),
#   ('not', 'PART'),
#   ('.', 'PUNCT'),
#   ('t', 'PROPN'),
#   ("'s", 'PART'),
#   ('pretty', 'ADJ'),
#   ('bomb', 'NOUN'),
#   (',', 'PUNCT'),
#   ('it', 'PRON'),
#   ('be', 'AUX'),
#   ('light', 'VERB'),
#   (',', 'PUNCT'),
#   (' ', 'SPACE'),
#   ('it', 'PRON'),
#   ('be', 'AUX'),
#   ('groovy', 'NOUN'),
#   (',', 'PUNCT'),
#   ('it', 'PRON'),
#   ('be', 'AUX'),
#   ('fab', 'NOUN'),
#   (',', 'PUNCT'),
#   ('it', 'PRON'),
#   ('be', 'AUX'),
#   ('far', 'ADV'),
#   ('out', 'ADV'),
#   (',', 'PUNCT'),
#   ('man', 'INTJ'),
#   (',', 'PUNCT'),
#   ('it', 'PRON'),
#   ('be', 'AUX'),
#   ('a', 'DET'),
#   ('gas', 'NOUN'),
#   (',', 'PUNCT'),
#   ('i', 'PRON'),
#   ('fully', 'ADV'),
#   ('dig', 'VERB'),
#   ('it', 'PRON'),
#   ('.', 'PUNCT'),
#   ('free', 'ADJ'),
#   ('love', 'NOUN'),
#   (',', 'PUNCT'),
#   ('give', 'VERB'),
#   ('peace', 'NOUN'),
#   ('a', 'DET'),
#   ('chance', 'NOUN'),
#   (',', 'PUNCT'),
#   ('nixon', 'PROPN'),
#   ("'s", 'PART'),
#   ('a', 'DET'),
#   ('fascist', 'NOUN'),
#   ('.', 'PUNCT'),
#   ('so', 'ADV'),
#   ('back', 'ADV'),
#   ('in', 'ADP'),
#   ('may', 'PROPN'),
#   ('of', 'ADP'),
#   ('this', 'DET'),
#   ('year', 'NOUN'),
#   (',', 'PUNCT'),
#   ('james', 'PROPN'),
#   ("'s", 'PART'),
#   ('colleague', 'NOUN'),
#   ('and', 'CCONJ'),
#   ('...', 'PUNCT'),
#   ('mother', 'NOUN'),
#   ('figure', 'NOUN'),
#   ('?', 'PUNCT'),
#   ('fellow', 'PROPN'),
#   ('youtube', 'PROPN'),
#   ('beauty', 'NOUN'),
#   ('guru', 'NOUN'),
#   (',', 'PUNCT'),
#   ('tati', 'PROPN'),
#   ('westbrook', 'PROPN'),
#   (',', 'PUNCT'),
#   ('upload', 'VERB'),
#   ('a', 'DET'),
#   ('40', 'NUM'),
#   ('-', 'PUNCT'),
#   ('minute', 'NOUN'),
#   ('video', 'NOUN'),
#   ('accuse', 'VERB'),
#   ('james', 'PROPN'),
#   ('of', 'ADP'),
#   ('endorse', 'VERB'),
#   ('a', 'DET'),
#   ('brand', 'NOUN'),
#   ('of', 'ADP'),
#   ('hair', 'NOUN'),
#   ('vitamin', 'NOUN'),
#   ('that', 'SCONJ'),
#   ('she', 'PRON'),
#   (',', 'PUNCT'),
#   ('wait', 'VERB'),
#   (',', 'PUNCT'),
#   ('that', 'PRON'),
#   ('be', 'AUX'),
#   ('a', 'DET'),
#   ('competitor', 'NOUN'),
#   ('of', 'ADP'),
#   ('her', 'PRON'),
#   ('brand', 'NOUN'),
#   ('of', 'ADP'),
#   ('hair', 'NOUN'),
#   ('vitamin', 'NOUN'),
#   ('.', 'PUNCT'),
#   ('an', 'DET'),
#   ('enthralling', 'ADJ'),
#   ('plot', 'NOUN'),
#   ('line', 'NOUN'),
#   (',', 'PUNCT'),
#   ('i', 'PRON'),
#   ('know', 'VERB'),
#   ('.', 'PUNCT'),
#   ('and', 'CCONJ'),
#   ('this', 'PRON'),
#   ('be', 'AUX'),
#   ('huge', 'ADJ'),
#   (',', 'PUNCT'),
#   ('this', 'PRON'),
#   ('be', 'AUX'),
#   ('cover', 'VERB'),
#   ('in', 'ADP'),
#   ('the', 'DET'),
#   ('new', 'PROPN'),
#   ('york', 'PROPN'),
#   ('times', 'PROPN'),
#   ('.', 'PUNCT'),
#   ('and', 'CCONJ'),
#   ('while', 'SCONJ'),
#   ('tati', 'PROPN'),
#   ('be', 'AUX'),
#   ('at', 'ADP'),
#   ('it', 'PRON'),
#   (',', 'PUNCT'),
#   ('almost', 'ADV'),
#   ('as', 'ADP'),
#   ('an', 'DET'),
#   ('afterthought', 'NOUN'),
#   ('to', 'ADP'),
#   ('the', 'DET'),
#   ('hair', 'NOUN'),
#   ('vitamin', 'NOUN'),
#   ('dispute', 'NOUN'),
#   (',', 'PUNCT'),
#   ('she', 'PRON'),
#   ('also', 'ADV'),
#   ('accuse', 'VERB'),
#   ('james', 'PROPN'),
#   ('of', 'ADP'),
#   ('be', 'AUX'),
#   ('a', 'DET'),
#   ('sexual', 'ADJ'),
#   ('predator', 'NOUN'),
#   ('.', 'PUNCT'),
#   ('now', 'INTJ'),
#   ('i', 'PRON'),
#   ('actually', 'ADV'),
#   ('go', 'VERB'),
#   ('back', 'ADV'),
#   ('and', 'CCONJ'),
#   ('check', 'VERB'),
#   ('tati', 'PROPN'),
#   ("'s", 'PART'),
#   ('original', 'ADJ'),
#   ('delete', 'VERB'),
#   ('video', 'NOUN'),
#   ('.', 'PUNCT'),
#   ('and', 'CCONJ'),
#   ('she', 'PRON'),
#   ('actually', 'ADV'),
#   ('never', 'ADV'),
#   ('use', 'VERB'),
#   ('the', 'DET'),
#   ('phrase', 'NOUN'),
#   ('sexual', 'ADJ'),
#   ('predator', 'NOUN'),
#   ('.', 'PUNCT'),
#   ('it', 'PRON'),
#   ('be', 'AUX'),
#   ('funny', 'ADJ'),
#   (',', 'PUNCT'),
#   ('i', 'PRON'),
#   ('remember', 'VERB'),
#   ('she', 'PRON'),
#   ('call', 'VERB'),
#   ('he', 'PRON'),
#   ('that', 'SCONJ'),
#   ('because', 'SCONJ'),
#   ('that', 'PRON'),
#   ('become', 'VERB'),
#   ('the', 'DET'),
#   ('story', 'NOUN'),
#   ('on', 'ADP'),
#   ('twitter', 'PROPN'),
#   ('.', 'PUNCT'),
#   ('but', 'CCONJ'),
#   ('what', 'PRON'),
#   ('she', 'PRON'),
#   ('actually', 'ADV'),
#   ('say', 'VERB'),
#   ('be', 'AUX'),
#   (',', 'PUNCT'),
#   ('"', 'PUNCT'),
#   ('james', 'PROPN'),
#   ('have', 'AUX'),
#   ('try', 'VERB'),
#   ('to', 'PART'),
#   ('trick', 'VERB'),
#   ('straight', 'ADJ'),
#   ('man', 'NOUN'),
#   ('"', 'PUNCT'),
#   ('into', 'ADP'),
#   ('thinking', 'NOUN'),
#   ('they', 'PRON'),
#   ('be', 'AUX'),
#   ('gay', 'ADJ'),
#   ('.', 'PUNCT'),
#   ('"', 'PUNCT'),
#   ('-', 'PUNCT'),
#   ('oh', 'INTJ'),
#   ('my', 'INTJ'),
#   ('god', 'INTJ'),
#   (',', 'PUNCT'),
#   ('you', 'PRON'),
#   ('try', 'VERB'),
#   ('to', 'PART'),
#   ('trick', 'VERB'),
#   ('a', 'DET'),
#   ('straight', 'ADJ'),
#   ('man', 'NOUN'),
#   ('into', 'ADP'),
#   ('think', 'VERB'),
#   ('he', 'PRON'),
#   ('be', 'AUX'),
#   ('gay', 'ADJ'),
#   (',', 'PUNCT'),
#   ('yet', 'CCONJ'),
#   ('again', 'ADV'),
#   ('.', 'PUNCT'),
#   ('-', 'PUNCT'),
#   ('which', 'PRON'),
#   ('be', 'AUX'),
#   ('pretty', 'ADV'),
#   ('different', 'ADJ'),
#   ('from', 'ADP'),
#   ('call', 'VERB'),
#   ('he', 'PRON'),
#   ('a', 'DET'),
#   ('sexual', 'ADJ'),
#   ('predator', 'NOUN'),
#   ('.', 'PUNCT'),
#   ('but', 'CCONJ'),
#   ('see', 'VERB'),
#   (',', 'PUNCT'),
#   ('this', 'PRON'),
#   ('be', 'AUX'),
#   ('what', 'PRON'),
#   ('cancel', 'VERB'),
#   ('culture', 'NOUN'),
#   ('do', 'VERB'),
#   (',', 'PUNCT'),
#   ('it', 'PRON'),
#   ('take', 'VERB'),
#   ('one', 'NUM'),
#   ('story', 'NOUN'),
#   ('and', 'CCONJ'),
#   ('transform', 'VERB'),
#   ('it', 'PRON'),
#   ('into', 'ADP'),
#   ('a', 'DET'),
#   ('significantly', 'ADV'),
#   ('different', 'ADJ'),
#   ('story', 'NOUN'),
#   ('.', 'PUNCT'),
#   ('you', 'PRON'),
#   ('know', 'VERB'),
#   (',', 'PUNCT'),
#   ('the', 'DET'),
#   ('headline', 'NOUN'),
#   ('i', 'PRON'),
#   ('would', 'AUX'),
#   ('write', 'VERB'),
#   ('about', 'ADP'),
#   ('the', 'DET'),
#   ('james', 'PROPN'),
#   ('and', 'CCONJ'),
#   ('tati', 'PROPN'),
#   ('story', 'NOUN'),
#   ('might', 'AUX'),
#   ('read', 'VERB'),
#   ('tati', 'PROPN'),
#   ('westbrook', 'PROPN'),
#   ('accuse', 'VERB'),
#   ('james', 'PROPN'),
#   ('charles', 'PROPN'),
#   ('of', 'ADP'),
#   ('try', 'VERB'),
#   ('to', 'PART'),
#   ('trick', 'VERB'),
#   ('straight', 'ADJ'),
#   ('man', 'NOUN'),
#   ('into', 'ADP'),
#   ('think', 'VERB'),
#   ('they', 'PRON'),
#   ('be', 'AUX'),
#   ('gay', 'ADJ'),
#   ('.', 'PUNCT'),
#   ('but', 'CCONJ'),
#   ('cancel', 'VERB'),
#   ('culture', 'NOUN'),
#   ('transform', 'VERB'),
#   ('that', 'DET'),
#   ('story', 'NOUN'),
#   ('into', 'ADP'),
#   ('the', 'DET'),
#   ('headline', 'NOUN'),
#   ('james', 'PROPN'),
#   ('charles', 'PROPN'),
#   ('be', 'AUX'),
#   ('a', 'DET'),
#   ('sexual', 'ADJ'),
#   ('predator', 'NOUN'),
#   ('.', 'PUNCT'),
#   ('interesting', 'ADJ'),
#   (',', 'PUNCT'),
#   ('now', 'ADV'),
#   (',', 'PUNCT'),
#   ('i', 'PRON'),
#   ('wanna', 'VERB'),
#   ('make', 'VERB'),
#   ('it', 'PRON'),
#   ('clear', 'ADJ'),
#   ('that', 'SCONJ'),
#   ('my', 'PRON'),
#   ('intention', 'NOUN'),
#   ('here', 'ADV'),
#   ('be', 'AUX'),
#   ('really', 'ADV'),
#   ('not', 'PART'),
#   ('to', 'PART'),
#   ('defend', 'VERB'),
#   ('james', 'PROPN'),
#   ('charles', 'PROPN'),
#   ('.', 'PUNCT'),
#   ('i', 'PRON'),
#   ('be', 'AUX'),
#   ('not', 'PART'),
#   ('a', 'DET'),
#   ...],
#  [('-', 'PUNCT'),
#   ('bubble', 'NOUN'),
#   (',', 'PUNCT'),
#   ('bubble', 'NOUN'),
#   ('toil', 'NOUN'),
#   ('and', 'CCONJ'),
#   ('trouble', 'NOUN'),
#   ('.', 'PUNCT'),
#   ('fire', 'NOUN'),
#   ('burn', 'VERB'),
#   ('and', 'CCONJ'),
#   ('cauldron', 'PROPN'),
#   ('bubble', 'NOUN'),
#   ('!', 'PUNCT'),
#   ('something', 'PRON'),
#   ('wicke', 'VERB'),
#   ('this', 'DET'),
#   ('way', 'NOUN'),
#   ('come', 'VERB'),
#   ('!', 'PUNCT'),
#   ('magical', 'ADJ'),
#   ('deed', 'NOUN'),
#   ('be', 'AUX'),
#   ('afoot', 'ADJ'),
#   ('dear', 'ADJ'),
#   ('reader', 'NOUN'),
#   (',', 'PUNCT'),
#   ('magical', 'ADJ'),
#   ('darkness', 'NOUN'),
#   ('a', 'DET'),
#   ('must', 'NOUN'),
#   ('.', 'PUNCT'),
#   ('joanne', 'PROPN'),
#   (',', 'PUNCT'),
#   ('i', 'PRON'),
#   ('wanna', 'VERB'),
#   ('talk', 'VERB'),
#   ('to', 'ADP'),
#   ('you', 'PRON'),
#   ('joanne', 'PROPN'),
#   ('!', 'PUNCT'),
#   ('what', 'PRON'),
#   ('be', 'AUX'),
#   ('it', 'PRON'),
#   ('about', 'ADP'),
#   ('joannes', 'PROPN'),
#   ('?', 'PUNCT'),
#   ('i', 'PRON'),
#   ('can', 'AUX'),
#   ('not', 'PART'),
#   ('catch', 'VERB'),
#   ('a', 'DET'),
#   ('break', 'NOUN'),
#   ('from', 'ADP'),
#   ('these', 'DET'),
#   ('people', 'NOUN'),
#   ('.', 'PUNCT'),
#   ('so', 'ADV'),
#   (',', 'PUNCT'),
#   ('now', 'ADV'),
#   ('that', 'SCONJ'),
#   ('2020', 'NUM'),
#   ('be', 'AUX'),
#   ('finally', 'ADV'),
#   ('over', 'ADV'),
#   (',', 'PUNCT'),
#   ('i', 'PRON'),
#   ('think', 'VERB'),
#   ('we', 'PRON'),
#   ('can', 'AUX'),
#   ('let', 'VERB'),
#   ('the', 'DET'),
#   ('record', 'NOUN'),
#   ('conclusively', 'ADV'),
#   ('show', 'VERB'),
#   ('that', 'SCONJ'),
#   ('it', 'PRON'),
#   ('be', 'AUX'),
#   ('a', 'DET'),
#   ('year', 'NOUN'),
#   ('whomst', 'NOUN'),
#   ('be', 'AUX'),
#   ('bad', 'ADJ'),
#   ('.', 'PUNCT'),
#   ('and', 'CCONJ'),
#   ('on', 'ADP'),
#   ('top', 'NOUN'),
#   ('of', 'ADP'),
#   ('everything', 'PRON'),
#   ('else', 'ADV'),
#   ('that', 'PRON'),
#   ('be', 'AUX'),
#   ('go', 'VERB'),
#   ('on', 'ADP'),
#   ('truly', 'ADV'),
#   ('the', 'DET'),
#   ('last', 'ADJ'),
#   ('thing', 'NOUN'),
#   ('we', 'PRON'),
#   ('need', 'VERB'),
#   ('be', 'AUX'),
#   ('the', 'DET'),
#   ('author', 'NOUN'),
#   ('of', 'ADP'),
#   ('harry', 'PROPN'),
#   ('potter', 'PROPN'),
#   ('come', 'VERB'),
#   ('forward', 'ADV'),
#   ('to', 'PART'),
#   ('announce', 'VERB'),
#   ('there', 'PRON'),
#   ('be', 'VERB'),
#   ('two', 'NUM'),
#   ('thing', 'NOUN'),
#   ('she', 'PRON'),
#   ('can', 'AUX'),
#   ('not', 'PART'),
#   ('stand', 'VERB'),
#   (':', 'PUNCT'),
#   ('bigotry', 'NOUN'),
#   (',', 'PUNCT'),
#   ('and', 'CCONJ'),
#   ('the', 'DET'),
#   ('transgender', 'NOUN'),
#   ('.', 'PUNCT'),
#   ('ow', 'NOUN'),
#   ('!', 'PUNCT'),
#   ('elderberry', 'ADJ'),
#   ('wand', 'NOUN'),
#   (',', 'PUNCT'),
#   ('turgid', 'ADJ'),
#   (',', 'PUNCT'),
#   ('with', 'ADP'),
#   ('a', 'DET'),
#   ('core', 'NOUN'),
#   ('of', 'ADP'),
#   ('...', 'PUNCT'),
#   ('icedragon', 'PROPN'),
#   ('.', 'PUNCT'),
#   ('lumos', 'PROPN'),
#   ('!', 'PUNCT'),
#   ('can', 'AUX'),
#   ('we', 'PRON'),
#   ('afford', 'VERB'),
#   ('spell', 'NOUN'),
#   ('?', 'PUNCT'),
#   ('be', 'AUX'),
#   ('that', 'PRON'),
#   ('in', 'ADP'),
#   ('the', 'DET'),
#   ('budget', 'NOUN'),
#   ('?', 'PUNCT'),
#   ('expecto', 'PROPN'),
#   ('patreon', 'PROPN'),
#   ('!', 'PUNCT'),
#   ('so', 'ADV'),
#   ('you', 'PRON'),
#   ("'ve", 'AUX'),
#   ('probably', 'ADV'),
#   ('hear', 'VERB'),
#   ('by', 'ADP'),
#   ('now', 'ADV'),
#   ('about', 'ADP'),
#   ('joanne', 'PROPN'),
#   ('rowling', 'PROPN'),
#   ("'s", 'PART'),
#   ('transphobic', 'NOUN'),
#   ('tweet', 'NOUN'),
#   (',', 'PUNCT'),
#   ('unless', 'SCONJ'),
#   ('you', 'PRON'),
#   ("'ve", 'AUX'),
#   ('be', 'AUX'),
#   ('live', 'VERB'),
#   ('under', 'ADP'),
#   ('a', 'DET'),
#   ('rock', 'NOUN'),
#   (',', 'PUNCT'),
#   ('in', 'ADP'),
#   ('which', 'DET'),
#   ('case', 'NOUN'),
#   ('get', 'VERB'),
#   ('back', 'ADV'),
#   ('under', 'ADP'),
#   ('that', 'DET'),
#   ('rock', 'NOUN'),
#   ('sweetie', 'NOUN'),
#   (',', 'PUNCT'),
#   ('there', 'PRON'),
#   ('be', 'VERB'),
#   ('nothing', 'PRON'),
#   ('good', 'ADJ'),
#   ('go', 'VERB'),
#   ('on', 'ADP'),
#   ('up', 'ADV'),
#   ('here', 'ADV'),
#   ('it', 'PRON'),
#   ('be', 'AUX'),
#   ('not', 'PART'),
#   ('worth', 'ADJ'),
#   ('it', 'PRON'),
#   ('.', 'PUNCT'),
#   ('or', 'CCONJ'),
#   ('maybe', 'ADV'),
#   ('you', 'PRON'),
#   ('hear', 'VERB'),
#   ('that', 'SCONJ'),
#   ('all', 'DET'),
#   ('joanne', 'PROPN'),
#   ('do', 'VERB'),
#   ('be', 'AUX'),
#   ('say', 'VERB'),
#   ('biological', 'ADJ'),
#   ('sex', 'NOUN'),
#   ('be', 'AUX'),
#   ('real', 'ADJ'),
#   (',', 'PUNCT'),
#   ('and', 'CCONJ'),
#   ('now', 'ADV'),
#   ('crazy', 'ADJ'),
#   ('gender', 'NOUN'),
#   ('ideologue', 'NOUN'),
#   ('and', 'CCONJ'),
#   ('transactivist', 'NOUN'),
#   ('be', 'AUX'),
#   ('try', 'VERB'),
#   ('to', 'PART'),
#   ('silence', 'VERB'),
#   ('she', 'PRON'),
#   ('.', 'PUNCT'),
#   ('this', 'PRON'),
#   ('be', 'AUX'),
#   ('cancel', 'ADJ'),
#   ('culture', 'NOUN'),
#   ('go', 'VERB'),
#   ('too', 'ADV'),
#   ('far', 'ADV'),
#   (',', 'PUNCT'),
#   ('this', 'PRON'),
#   ('be', 'AUX'),
#   ('a', 'DET'),
#   ('witch', 'NOUN'),
#   ('hunt', 'NOUN'),
#   ('.', 'PUNCT'),
#   ('celebrity', 'NOUN'),
#   ('be', 'AUX'),
#   ('under', 'ADP'),
#   ('attack', 'NOUN'),
#   ('.', 'PUNCT'),
#   ('this', 'PRON'),
#   ('be', 'AUX'),
#   ('the', 'DET'),
#   ('new', 'ADJ'),
#   ('salem', 'PROPN'),
#   ('.', 'PUNCT'),
#   ('this', 'PRON'),
#   ('be', 'AUX'),
#   ('orwell', 'PROPN'),
#   ("'s", 'PART'),
#   ('nightmare', 'NOUN'),
#   ('.', 'PUNCT'),
#   ('this', 'PRON'),
#   ('be', 'AUX'),
#   ('a', 'DET'),
#   ('painful', 'ADJ'),
#   ('topic', 'NOUN'),
#   ('for', 'ADP'),
#   ('i', 'PRON'),
#   ('all', 'ADV'),
#   ('around', 'ADV'),
#   ('because', 'SCONJ'),
#   (',', 'PUNCT'),
#   ('as', 'ADP'),
#   ('a', 'DET'),
#   ('transgender', 'NOUN'),
#   ('woman', 'NOUN'),
#   (',', 'PUNCT'),
#   ('i', 'PRON'),
#   ('be', 'AUX'),
#   ('honestly', 'ADV'),
#   ('really', 'ADV'),
#   ('hurt', 'VERB'),
#   ('by', 'ADP'),
#   ('a', 'DET'),
#   ('lot', 'NOUN'),
#   ('of', 'ADP'),
#   ('the', 'DET'),
#   ('thing', 'NOUN'),
#   ('joanne', 'PROPN'),
#   ('have', 'AUX'),
#   ('say', 'VERB'),
#   ('in', 'ADP'),
#   ('the', 'DET'),
#   ('last', 'ADJ'),
#   ('year', 'NOUN'),
#   ('.', 'PUNCT'),
#   ('but', 'CCONJ'),
#   ('i', 'PRON'),
#   ('also', 'ADV'),
#   ('know', 'VERB'),
#   ('what', 'PRON'),
#   ('it', 'PRON'),
#   ('be', 'AUX'),
#   ('like', 'ADP'),
#   ('to', 'PART'),
#   ('be', 'AUX'),
#   ('the', 'DET'),
#   ('target', 'NOUN'),
#   ('of', 'ADP'),
#   ('a', 'DET'),
#   ('twitter', 'PROPN'),
#   ('mob', 'NOUN'),
#   ('.', 'PUNCT'),
#   ('and', 'CCONJ'),
#   ('i', 'PRON'),
#   ('realize', 'VERB'),
#   ('that', 'PRON'),
#   ('to', 'ADP'),
#   ('most', 'ADJ'),
#   ('people', 'NOUN'),
#   (',', 'PUNCT'),
#   ('complain', 'VERB'),
#   ('about', 'ADP'),
#   ('"', 'PUNCT'),
#   ('be', 'AUX'),
#   ('cancel', 'VERB'),
#   (',', 'PUNCT'),
#   ('waahh"-', 'VERB'),
#   ('it', 'PRON'),
#   ('sound', 'VERB'),
#   ('incredibly', 'ADV'),
#   ('whiny', 'ADJ'),
#   ('and', 'CCONJ'),
#   ('self', 'NOUN'),
#   ('-', 'PUNCT'),
#   ('absorb', 'VERB'),
#   ('.', 'PUNCT'),
#   ('like', 'ADP'),
#   ('you', 'PRON'),
#   ('would', 'AUX'),
#   ('especially', 'ADV'),
#   ('think', 'VERB'),
#   ('that', 'SCONJ'),
#   ('rich', 'ADJ'),
#   ('and', 'CCONJ'),
#   ('famous', 'ADJ'),
#   ('people', 'NOUN'),
#   ('like', 'ADP'),
#   ('j.k.', 'PROPN'),
#   ('rowling', 'PROPN'),
#   ('would', 'AUX'),
#   ('be', 'AUX'),
#   ('above', 'ADP'),
#   ('stay', 'VERB'),
#   ('up', 'ADV'),
#   ('alone', 'ADV'),
#   ('at', 'ADP'),
#   ('night', 'NOUN'),
#   (',', 'PUNCT'),
#   ('read', 'VERB'),
#   ('mean', 'ADJ'),
#   ('thing', 'NOUN'),
#   ('people', 'NOUN'),
#   ('say', 'VERB'),
#   ('online', 'ADV'),
#   ('.', 'PUNCT'),
#   ('but', 'CCONJ'),
#   ('you', 'PRON'),
#   ('would', 'AUX'),
#   ('think', 'VERB'),
#   ('wrong', 'ADV'),
#   ('.', 'PUNCT'),
#   ('see', 'VERB'),
#   (',', 'PUNCT'),
#   ('you', 'PRON'),
#   ('underestimate', 'VERB'),
#   ('the', 'DET'),
#   ('fundamental', 'ADJ'),
#   ('sadness', 'NOUN'),
#   ('of', 'ADP'),
#   ('the', 'DET'),
#   ('human', 'ADJ'),
#   ('condition', 'NOUN'),
#   ('.', 'PUNCT'),
#   ('and', 'CCONJ'),
#   ('no', 'DET'),
#   ('amount', 'NOUN'),
#   ('of', 'ADP'),
#   ('fame', 'NOUN'),
#   ('and', 'CCONJ'),
#   ('money', 'NOUN'),
#   ('be', 'AUX'),
#   ('going', 'VERB'),
#   ('to', 'PART'),
#   ('fix', 'VERB'),
#   ('that', 'PRON'),
#   ('.', 'PUNCT'),
#   ('you', 'PRON'),
#   ('know', 'VERB'),
#   (',', 'PUNCT'),
#   ('fame', 'NOUN'),
#   ('alienate', 'VERB'),
#   ('you', 'PRON'),
#   ('from', 'ADP'),
#   ('other', 'ADJ'),
#   ('people', 'NOUN'),
#   (',', 'PUNCT'),
#   ('it', 'PRON'),
#   ('dehumanize', 'VERB'),
#   ('you', 'PRON'),
#   ('in', 'ADP'),
#   ('the', 'DET'),
#   ('eye', 'NOUN'),
#   ('of', 'ADP'),
#   ('the', 'DET'),
#   ('masse', 'NOUN'),
#   (',', 'PUNCT'),
#   ('which', 'PRON'),
#   ('can', 'AUX'),
#   ('actually', 'ADV'),
#   ('make', 'VERB'),
#   ('you', 'PRON'),
#   ('feel', 'VERB'),
#   ('more', 'ADV'),
#   ('alone', 'ADJ'),
#   ('even', 'ADV'),
#   ('when', 'SCONJ'),
#   ('people', 'NOUN'),
#   ('be', 'AUX'),
#   ('worship', 'VERB'),
#   ('you', 'PRON'),
#   ('as', 'ADP'),
#   ('a', 'DET'),
#   ('goddess', 'NOUN'),
#   (',', 'PUNCT'),
#   ('never', 'ADV'),
#   ('mind', 'VERB'),
#   ('how', 'SCONJ'),
#   ('it', 'PRON'),
#   ('feel', 'VERB'),
#   ('when', 'SCONJ'),
#   ('they', 'PRON'),
#   ('be', 'AUX'),
#   ('hunt', 'VERB'),
#   ('you', 'PRON'),
#   ('as', 'ADP'),
#   ('a', 'DET'),
#   ('witch', 'NOUN'),
#   ('.', 'PUNCT'),
# ...
#   (',', 'PUNCT'),
#   ('do', 'AUX'),
#   ('not', 'PART'),
#   ('hasan', 'PROPN'),
#   ('piker', 'VERB'),
#   ('i', 'PRON'),
#   ('!', 'PUNCT'),
#   ('i', 'PRON'),
#   ('be', 'AUX'),
#   ('going', 'VERB'),
#   ('to', 'PART'),
#   ('be', 'AUX'),
#   ('as', 'ADV'),
#   ('honest', 'ADJ'),
#   ('here', 'ADV'),
#   ('as', 'SCONJ'),
#   ('i', 'PRON'),
#   ('can', 'AUX'),
#   ('.', 'PUNCT'),
#   ('i', 'PRON'),
#   ('write', 'VERB'),
#   ('quite', 'DET'),
#   ('a', 'DET'),
#   ('few', 'ADJ'),
#   ('draft', 'NOUN'),
#   ('of', 'ADP'),
#   ('this', 'DET'),
#   ('script', 'NOUN'),
#   (',', 'PUNCT'),
#   ('bake', 'VERB'),
#   ('a', 'DET'),
#   ('cake', 'NOUN'),
#   ('and', 'CCONJ'),
#   ('talk', 'VERB'),
#   ('about', 'ADP'),
#   ('the', 'DET'),
#   ('philosophy', 'NOUN'),
#   ('of', 'ADP'),
#   ('food', 'NOUN'),
#   (',', 'PUNCT'),
#   ('and', 'CCONJ'),
#   ('they', 'PRON'),
#   ('be', 'AUX'),
#   ('all', 'ADV'),
#   ('fine', 'ADJ'),
#   ('.', 'PUNCT'),
#   ('but', 'CCONJ'),
#   ('about', 'ADV'),
#   ('a', 'PRON'),
#   ('week', 'NOUN'),
#   ('before', 'ADP'),
#   ('film', 'VERB'),
#   (',', 'PUNCT'),
#   ('i', 'PRON'),
#   ('realise', 'VERB'),
#   ('that', 'SCONJ'),
#   ('in', 'ADP'),
#   ('every', 'DET'),
#   ('draft', 'NOUN'),
#   (',', 'PUNCT'),
#   ('the', 'DET'),
#   ('episode', 'NOUN'),
#   ('always', 'ADV'),
#   ('end', 'VERB'),
#   ('when', 'SCONJ'),
#   ('the', 'DET'),
#   ('cake', 'NOUN'),
#   ('be', 'AUX'),
#   ('do', 'VERB'),
#   (',', 'PUNCT'),
#   ('i', 'PRON'),
#   ('never', 'ADV'),
#   ('actually', 'ADV'),
#   ('eat', 'VERB'),
#   ('any', 'PRON'),
#   ('of', 'ADP'),
#   ('it', 'PRON'),
#   ('.', 'PUNCT'),
#   ('and', 'CCONJ'),
#   ('i', 'PRON'),
#   ('realise', 'VERB'),
#   ('that', 'SCONJ'),
#   ('i', 'PRON'),
#   ('be', 'AUX'),
#   ('afraid', 'ADJ'),
#   ('to', 'PART'),
#   ('be', 'AUX'),
#   ('see', 'VERB'),
#   ('on', 'ADP'),
#   ('camera', 'NOUN'),
#   ('eat', 'VERB'),
#   ('a', 'DET'),
#   ('slice', 'NOUN'),
#   ('of', 'ADP'),
#   ('cake', 'NOUN'),
#   (',', 'PUNCT'),
#   ('and', 'CCONJ'),
#   ('it', 'PRON'),
#   ('hit', 'VERB'),
#   ('i', 'PRON'),
#   ('like', 'ADP'),
#   ('a', 'DET'),
#   ('truck', 'NOUN'),
#   ('.', 'PUNCT'),
#   ('jesus', 'PROPN'),
#   (',', 'PUNCT'),
#   ('this', 'DET'),
#   ('video', 'NOUN'),
#   ('be', 'AUX'),
#   ('not', 'PART'),
#   ('about', 'ADP'),
#   ('food', 'NOUN'),
#   (',', 'PUNCT'),
#   ('or', 'CCONJ'),
#   ('it', 'PRON'),
#   ('be', 'AUX'),
#   ('not', 'PART'),
#   ('just', 'ADV'),
#   ('about', 'ADP'),
#   ('food', 'NOUN'),
#   (',', 'PUNCT'),
#   ('it', 'PRON'),
#   ('be', 'AUX'),
#   ('about', 'ADP'),
#   ('fatphobia', 'PROPN'),
#   (',', 'PUNCT'),
#   ('and', 'CCONJ'),
#   ('beauty', 'NOUN'),
#   ('standard', 'NOUN'),
#   (',', 'PUNCT'),
#   ('and', 'CCONJ'),
#   ('shame', 'NOUN'),
#   (',', 'PUNCT'),
#   ('and', 'CCONJ'),
#   ('womanhood', 'NOUN'),
#   (',', 'PUNCT'),
#   ('and', 'CCONJ'),
#   ('eat', 'VERB'),
#   ('disorder', 'NOUN'),
#   (',', 'PUNCT'),
#   ('and', 'CCONJ'),
#   ('cosmetic', 'ADJ'),
#   ('surgery', 'NOUN'),
#   (',', 'PUNCT'),
#   ('and', 'CCONJ'),
#   ('ultimately', 'ADV'),
#   ('it', 'PRON'),
#   ('be', 'AUX'),
#   ('about', 'ADP'),
#   ('the', 'DET'),
#   ('philosophy', 'NOUN'),
#   ('of', 'ADP'),
#   ('mind', 'NOUN'),
#   ('.', 'PUNCT'),
#   ('and', 'CCONJ'),
#   ('i', 'PRON'),
#   ('think', 'VERB'),
#   ('this', 'PRON'),
#   ('be', 'AUX'),
#   ('probably', 'ADV'),
#   ('going', 'VERB'),
#   ('to', 'PART'),
#   ('be', 'AUX'),
#   ('really', 'ADV'),
#   ('very', 'ADV'),
#   ('hard', 'ADJ'),
#   ('for', 'ADP'),
#   ('i', 'PRON'),
#   (',', 'PUNCT'),
#   ('but', 'CCONJ'),
#   ('this', 'DET'),
#   ('episode', 'NOUN'),
#   ('be', 'AUX'),
#   ('go', 'VERB'),
#   ('to', 'PART'),
#   ('end', 'VERB'),
#   ('with', 'ADP'),
#   ('i', 'PRON'),
#   ('eat', 'VERB'),
#   ('this', 'DET'),
#   ('goddamn', 'ADJ'),
#   ('slice', 'NOUN'),
#   ('of', 'ADP'),
#   ('cake', 'NOUN'),
#   ('!', 'PUNCT'),
#   ('the', 'DET'),
#   ('first', 'ADJ'),
#   ('thing', 'NOUN'),
#   ('we', 'PRON'),
#   ('be', 'AUX'),
#   ('go', 'VERB'),
#   ('to', 'PART'),
#   ('do', 'VERB'),
#   ('be', 'AUX'),
#   ('wash', 'VERB'),
#   ('our', 'PRON'),
#   ('hand', 'NOUN'),
#   ('until', 'SCONJ'),
#   ('they', 'PRON'),
#   ('be', 'AUX'),
#   ('squeaky', 'ADV'),
#   ('clean', 'ADJ'),
#   ('.', 'PUNCT'),
#   ('and', 'CCONJ'),
#   ('then', 'ADV'),
#   (',', 'PUNCT'),
#   ('let', 'VERB'),
#   ('us', 'PRON'),
#   ('take', 'VERB'),
#   ('a', 'DET'),
#   ('look', 'NOUN'),
#   ('at', 'ADP'),
#   ('our', 'PRON'),
#   ('ingredient', 'NOUN'),
#   ('.', 'PUNCT'),
#   ('we', 'PRON'),
#   ('have', 'VERB'),
#   ('butter', 'NOUN'),
#   (',', 'PUNCT'),
#   ('caster', 'NOUN'),
#   ('sugar', 'NOUN'),
#   (',', 'PUNCT'),
#   ('two', 'NUM'),
#   ('lemon', 'NOUN'),
#   (',', 'PUNCT'),
#   ('elderflower', 'NOUN'),
#   ('cordial', 'PROPN'),
#   (',', 'PUNCT'),
#   ('three', 'NUM'),
#   ('egg', 'NOUN'),
#   (',', 'PUNCT'),
#   ('granulate', 'VERB'),
#   ('sugar', 'NOUN'),
#   (',', 'PUNCT'),
#   ('flour', 'NOUN'),
#   (',', 'PUNCT'),
#   ('bake', 'VERB'),
#   ('powder', 'NOUN'),
#   (',', 'PUNCT'),
#   ('salt', 'NOUN'),
#   ('-', 'PUNCT'),
#   ('a', 'DET'),
#   ('cultural', 'ADJ'),
#   ('history', 'NOUN'),
#   ('of', 'ADP'),
#   ('dieting', 'NOUN'),
#   ('!', 'PUNCT'),
#   ('-', 'PUNCT'),
#   ('ground', 'NOUN'),
#   ('almond', 'NOUN'),
#   ('and', 'CCONJ'),
#   ('poppy', 'ADJ'),
#   ('seed', 'NOUN'),
#   ('.', 'PUNCT'),
#   ('the', 'DET'),
#   ('poppy', 'ADJ'),
#   ('seed', 'NOUN'),
#   ('be', 'AUX'),
#   ('my', 'PRON'),
#   ('own', 'ADJ'),
#   ('little', 'ADJ'),
#   ('addition', 'NOUN'),
#   ('.', 'PUNCT'),
#   ('you', 'PRON'),
#   ('do', 'AUX'),
#   ('not', 'PART'),
#   (',', 'PUNCT'),
#   ('mind', 'NOUN'),
#   ('do', 'VERB'),
#   ('you', 'PRON'),
#   (',', 'PUNCT'),
#   ('nigella', 'PROPN'),
#   ('?', 'PUNCT'),
#   ('i', 'PRON'),
#   ('be', 'AUX'),
#   ('go', 'VERB'),
#   ('to', 'PART'),
#   ('start', 'VERB'),
#   ('off', 'ADP'),
#   ('by', 'ADP'),
#   ('mix', 'VERB'),
#   ('our', 'PRON'),
#   ('dry', 'ADJ'),
#   ('ingredient', 'NOUN'),
#   (',', 'PUNCT'),
#   ('and', 'CCONJ'),
#   ('we', 'PRON'),
#   ("'ll", 'AUX'),
#   ('get', 'VERB'),
#   ('to', 'ADP'),
#   ('the', 'DET'),
#   ('sweet', 'ADJ'),
#   ('stuff', 'NOUN'),
#   ('in', 'ADP'),
#   ('a', 'DET'),
#   ('bit', 'NOUN'),
#   ('.', 'PUNCT'),
#   ('philosopher', 'NOUN'),
#   ('distinguish', 'VERB'),
#   ('between', 'ADP'),
#   ('object', 'NOUN'),
#   (',', 'PUNCT'),
#   ('like', 'ADP'),
#   ('this', 'DET'),
#   ('recipe', 'NOUN'),
#   ('book', 'NOUN'),
#   (',', 'PUNCT'),
#   ('and', 'CCONJ'),
#   ('subject', 'NOUN'),
#   (',', 'PUNCT'),
#   ('people', 'NOUN'),
#   ('like', 'ADP'),
#   ('i', 'PRON'),
#   ('and', 'CCONJ'),
#   ('you', 'PRON'),
#   ('and', 'CCONJ'),
#   ('nigella', 'PROPN'),
#   ('.', 'PUNCT'),
#   ('and', 'CCONJ'),
#   ('they', 'PRON'),
#   ('wonder', 'VERB'),
#   ('what', 'PRON'),
#   ('the', 'DET'),
#   ('difference', 'NOUN'),
#   ('really', 'ADV'),
#   ('be', 'AUX'),
#   ('between', 'ADP'),
#   ('the', 'DET'),
#   ('two', 'NUM'),
#   ('.', 'PUNCT'),
#   ('what', 'PRON'),
#   ('do', 'AUX'),
#   ('it', 'PRON'),
#   ('mean', 'VERB'),
#   ('to', 'PART'),
#   ('be', 'AUX'),
#   ('a', 'DET'),
#   ('subject', 'NOUN'),
#   ('?', 'PUNCT'),
#   ('what', 'PRON'),
#   ('do', 'AUX'),
#   ('it', 'PRON'),
#   ('mean', 'VERB'),
#   ('to', 'PART'),
#   ('treat', 'VERB'),
#   ('a', 'DET'),
#   ('subject', 'NOUN'),
#   ('as', 'SCONJ'),
#   ('if', 'SCONJ'),
#   ('she', 'PRON'),
#   ('be', 'AUX'),
#   ('an', 'DET'),
#   ('object', 'NOUN'),
#   ('?', 'PUNCT'),
#   ('and', 'CCONJ'),
#   ('it', 'PRON'),
#   ('turn', 'VERB'),
#   ('out', 'ADP'),
#   ('that', 'SCONJ'),
#   ('food', 'NOUN'),
#   ('can', 'AUX'),
#   ('tell', 'VERB'),
#   ('we', 'PRON'),
#   ('a', 'DET'),
#   ('lot', 'NOUN'),
#   ('.', 'PUNCT'),
#   ('the', 'DET'),
#   ('english', 'ADJ'),
#   ('philosopher', 'NOUN'),
#   ('john', 'PROPN'),
#   ('locke', 'PROPN'),
#   ('say', 'VERB'),
#   ('that', 'SCONJ'),
#   ('when', 'SCONJ'),
#   ('people', 'NOUN'),
#   ('be', 'AUX'),
#   ('bear', 'VERB'),
#   (',', 'PUNCT'),
#   ('we', 'PRON'),
#   ('be', 'AUX'),
#   ('totally', 'ADV'),
#   ('blank', 'ADJ'),
#   ('slate', 'NOUN'),
#   (',', 'PUNCT'),
#   ('"', 'PUNCT'),
#   ('tabula', 'PROPN'),
#   ('rasa', 'VERB'),
#   ('"', 'PUNCT'),
#   ('for', 'ADP'),
#   ('any', 'DET'),
#   ('ancient', 'ADJ'),
#   ('romans', 'PROPN'),
#   ('in', 'ADP'),
#   ('the', 'DET'),
#   ('audience', 'NOUN'),
#   ('.', 'PUNCT'),
#   ('and', 'CCONJ'),
#   ('over', 'ADP'),
#   ('time', 'NOUN'),
#   (',', 'PUNCT'),
#   ('we', 'PRON'),
#   ('experience', 'VERB'),
#   ('the', 'DET'),
#   ('world', 'NOUN'),
#   ('.', 'PUNCT'),
#   ('we', 'PRON'),
#   ('experience', 'VERB'),
#   ('a', 'DET'),
#   ('little', 'ADJ'),
#   ('bit', 'NOUN'),
#   ('of', 'ADP'),
#   ('this', 'PRON'),
#   ('and', 'CCONJ'),
#   ('a', 'DET'),
#   ('little', 'ADJ'),
#   ('bit', 'NOUN'),
#   ('of', 'ADP'),
#   ('that', 'PRON'),
#   ('.', 'PUNCT'),
#   ('and', 'CCONJ'),
#   ('that', 'PRON'),
#   ('be', 'AUX'),
#   ('where', 'SCONJ'),
#   ('we', 'PRON'),
#   ('get', 'VERB'),
#   ('all', 'DET'),
#   ('our', 'PRON'),
#   ('idea', 'NOUN'),
#   ('and', 'CCONJ'),
#   ('concept', 'NOUN'),
#   ('from', 'ADP'),
#   ('.', 'PUNCT'),
#   ('i', 'PRON'),
#   ('be', 'AUX'),
#   ('give', 'VERB'),
#   ('locke', 'PROPN'),
#   ('credit', 'NOUN'),
#   ('for', 'ADP'),
#   ('this', 'DET'),
#   ('idea', 'NOUN'),
#   ('today', 'NOUN'),
#   (',', 'PUNCT'),
#   ('even', 'ADV'),
#   ('though', 'SCONJ'),
#   ('similar', 'ADJ'),
#   ('thing', 'NOUN'),
#   ('be', 'AUX'),
#   ('say', 'VERB'),
#   ('early', 'ADV'),
#   ('by', 'ADP'),
#   ('the', 'DET'),
#   ('medieval', 'ADJ'),
#   ('islamic', 'ADJ'),
#   ('philosopher', 'NOUN'),
#   ('avicenna', 'PROPN'),
#   ('.', 'PUNCT'),
#   ('the', 'DET'),
#   ('idea', 'NOUN'),
#   ('that', 'SCONJ'),
#   ('knowledge', 'NOUN'),
#   ('have', 'AUX'),
#   ('to', 'PART'),
#   ('come', 'VERB'),
#   ('from', 'ADP'),
#   ('experience', 'NOUN'),
#   ('be', 'AUX'),
#   ('call', 'VERB'),
#   ('empiricism', 'NOUN'),
#   ('.', 'PUNCT'),
#   ('and', 'CCONJ'),
#   ('we', 'PRON'),
#   ('can', 'AUX'),
#   ('apply', 'VERB'),
#   ('it', 'PRON'),
#   ('to', 'ADP'),
#   ('knowledge', 'NOUN'),
#   ('of', 'ADP'),
#   ('the', 'DET'),
#   ('subject', 'NOUN'),
#   (',', 'PUNCT'),
#   ('this', 'DET'),
#   ('"', 'PUNCT'),
#   ('i.', 'NOUN'),
#   ('"', 'PUNCT'),
#   ('the', 'DET'),
#   ('scottish', 'ADJ'),
#   ('philosopher', 'NOUN'),
#   ('david', 'PROPN'),
#   ('hume', 'PROPN'),
#   ('examine', 'VERB'),
#   ('all', 'DET'),
#   ('his', 'PRON'),
#   ('perception', 'NOUN'),
#   ('of', 'ADP'),
#   ('sweet', 'ADJ'),
#   ('and', 'CCONJ'),
#   ('salty', 'ADJ'),
#   (',', 'PUNCT'),
#   ('sour', 'ADJ'),
#   ('and', 'CCONJ'),
#   ('bitter', 'ADJ'),
#   (',', 'PUNCT'),
#   ('and', 'CCONJ'),
#   ('find', 'VERB'),
#   ('that', 'SCONJ'),
#   ('he', 'PRON'),
#   ('could', 'AUX'),
#   ('never', 'ADV'),
#   ('have', 'VERB'),
#   ('an', 'DET'),
#   ('experience', 'NOUN'),
#   ('just', 'ADV'),
#   ('of', 'ADP'),
#   ('"', 'PUNCT'),
#   ('i', 'PRON'),
#   ('"', 'PUNCT'),
#   ('on', 'ADP'),
#   ('its', 'PRON'),
#   ('own', 'ADJ'),
#   ('.', 'PUNCT'),
#   ('"', 'PUNCT'),
#   ('when', 'SCONJ'),
#   ('i', 'PRON'),
#   ('enter', 'VERB'),
#   ('most', 'ADV'),
#   ('intimately', 'ADV'),
#   ('into', 'ADP'),
#   ('what', 'PRON'),
#   ('i', 'PRON'),
#   ('call', 'VERB'),
#   ('myself', 'PRON'),
#   (',', 'PUNCT'),
#   ('"', 'PUNCT'),
#   ('i', 'PRON'),
#   ('always', 'ADV'),
#   ('stumble', 'VERB'),
#   ('on', 'ADP'),
#   ('some', 'DET'),
#   ('particular', 'ADJ'),
#   ('perception', 'NOUN'),
#   ('or', 'CCONJ'),
#   ('other', 'ADJ'),
#   (',', 'PUNCT'),
#   ('"', 'PUNCT'),
#   ('of', 'ADP'),
#   ('heat', 'NOUN'),
#   ('or', 'CCONJ'),
#   ('cold', 'ADJ'),
#   (',', 'PUNCT'),
#   ('light', 'ADJ'),
#   ('or', 'CCONJ'),
#   ('shade', 'ADJ'),
#   (',', 'PUNCT'),
#   ('"', 'PUNCT'),
#   ('love', 'NOUN'),
#   ('or', 'CCONJ'),
#   ('hatred', 'NOUN'),
#   (',', 'PUNCT'),
#   ('pain', 'NOUN'),
#   ('or', 'CCONJ'),
#   ('pleasure', 'NOUN'),
#   ('.', 'PUNCT'),
#   ('"', 'PUNCT'),
#   ('i', 'PRON'),
#   ('never', 'ADV'),
#   ('can', 'AUX'),
#   ('catch', 'VERB'),
#   ('myself', 'PRON'),
#   ('at', 'ADP'),
#   ('any', 'DET'),
#   ('time', 'NOUN'),
#   ('without', 'ADP'),
#   ('a', 'DET'),
#   ('perception', 'NOUN'),
#   ('"', 'PUNCT'),
#   ('and', 'CCONJ'),
#   ('never', 'ADV'),
#   ('can', 'AUX'),
#   ('observe', 'VERB'),
#   ('anything', 'PRON'),
#   ('but', 'SCONJ'),
#   ('the', 'DET'),
#   ('perception', 'NOUN'),
#   ('.', 'PUNCT'),
#   ('"', 'PUNCT'),
#   ('i', 'PRON'),
#   ('may', 'AUX'),
#   ('venture', 'VERB'),
#   ('to', 'PART'),
#   ('affirm', 'VERB'),
#   ('of', 'ADP'),
#   ('the', 'DET'),
#   ('rest', 'NOUN'),
#   ('of', 'ADP'),
#   ('mankind', 'NOUN'),
#   (',', 'PUNCT'),
#   ('"', 'PUNCT'),
#   ('that', 'SCONJ'),
#   ('they', 'PRON'),
#   ('be', 'AUX'),
#   ('nothing', 'PRON'),
#   ('but', 'SCONJ'),
#   ('a', 'DET'),
#   ('bundle', 'NOUN'),
#   ('or', 'CCONJ'),
#   ('collection', 'NOUN'),
#   ('"', 'PUNCT'),
#   ('of', 'ADP'),
#   ('different', 'ADJ'),
#   ('perception', 'NOUN'),
#   ('.', 'PUNCT'),
#   ('"', 'PUNCT'),
#   ('which', 'PRON'),
#   ('i', 'PRON'),
#   ('suppose', 'VERB'),
#   ('be', 'AUX'),
#   ('quite', 'ADV'),
#   ('intuitive', 'ADJ'),
#   ('.', 'PUNCT'),
#   ('just', 'ADV'),
#   ('i', 'PRON'),
#   ('personally', 'ADV'),
#   (',', 'PUNCT'),
#   ('i', 'PRON'),
#   ('find', 'VERB'),
#   ('it', 'PRON'),
#   ('difficult', 'ADJ'),
#   ('to', 'PART'),
#   ('imagine', 'VERB'),
#   ('a', 'DET'),
#   ('subject', 'NOUN'),
#   ('who', 'PRON'),
#   ('have', 'VERB'),
#   ('no', 'DET'),
#   ('perception', 'NOUN'),
#   ('at', 'ADV'),
#   ('all', 'ADV'),
#   (',', 'PUNCT'),
#   ('not', 'PART'),
#   ('a', 'DET'),
#   ('single', 'ADJ'),
#   ('point', 'NOUN'),
#   ('of', 'ADP'),
#   ('view', 'NOUN'),
#   ('.', 'PUNCT'),
#   ('that', 'PRON'),
#   ('be', 'AUX'),
#   ('like', 'ADP'),
#   ('be', 'AUX'),
#   ('dead', 'ADJ'),
#   (',', 'PUNCT'),
#   ('be', 'AUX'),
#   ('not', 'PART'),
#   ('it', 'PRON'),
#   ('?', 'PUNCT'),
#   ('in', 'ADP'),
#   ('which', 'DET'),
#   ('case', 'NOUN'),
#   (',', 'PUNCT'),
#   ('there', 'PRON'),
#   ('be', 'VERB'),
#   ('not', 'PART'),
#   ('a', 'DET'),
#   ('subject', 'NOUN'),
#   ('there', 'ADV'),
#   ('at', 'ADV'),
#   ('all', 'ADV'),
#   ('.', 'PUNCT'),
#   ('but', 'CCONJ'),
#   ('at', 'ADP'),
#   ('the', 'DET'),
#   ('same', 'ADJ'),
#   ('time', 'NOUN'),
#   (',', 'PUNCT'),
#   ('it', 'PRON'),
#   ('be', 'AUX'),
#   ('strange', 'ADJ'),
#   ('to', 'PART'),
#   ('imagine', 'VERB'),
#   ('a', 'DET'),
#   ('bunch', 'NOUN'),
#   ('of', 'ADP'),
#   ('perception', 'NOUN'),
#   ('float', 'VERB'),
#   ('around', 'ADV'),
#   ('with', 'ADP'),
#   ('nobody', 'PRON'),
#   ('have', 'VERB'),
#   ('they', 'PRON'),
#   ('.', 'PUNCT'),
#   ('the', 'DET'),
#   ('delicious', 'ADJ'),
#   ('smell', 'NOUN'),
#   ('of', 'ADP'),
#   ('hume', 'PROPN'),
#   ("'s", 'PART'),
#   ('empiricism', 'NOUN'),
#   ('waft', 'VERB'),
#   ('across', 'ADP'),
#   ('the', 'DET'),
#   ('sea', 'NOUN'),
#   ('to', 'ADP'),
#   ('prussia', 'PROPN'),
#   (',', 'PUNCT'),
#   ('where', 'SCONJ'),
#   ('it', 'PRON'),
#   ('be', 'AUX'),
#   ('nose', 'VERB'),
#   ('by', 'ADP'),
#   ('immanuel', 'PROPN'),
#   ('kant', 'PROPN'),
#   (',', 'PUNCT'),
#   ('very', 'ADV'),
#   ('much', 'ADV'),
#   ('the', 'DET'),
#   ('mary', 'PROPN'),
#   ('berry', 'PROPN'),
#   ('of', 'ADP'),
#   ('philosophy', 'NOUN'),
#   ('.', 'PUNCT'),
#   ('and', 'CCONJ'),
#   ('he', 'PRON'),
#   ('say', 'VERB'),
#   (',', 'PUNCT'),
#   ('"', 'PUNCT'),
#   ('hmm', 'INTJ'),
#   (',', 'PUNCT'),
#   ('the', 'DET'),
#   ('base', 'NOUN'),
#   ('be', 'AUX'),
#   ('good', 'ADJ'),
#   (',', 'PUNCT'),
#   ('"', 'PUNCT'),
#   ('but', 'CCONJ'),
#   ('i', 'PRON'),
#   ('think', 'VERB'),
#   ('you', 'PRON'),
#   ('could', 'AUX'),
#   ('have', 'AUX'),
#   ('do', 'VERB'),
#   ('well', 'ADV'),
#   ('"', 'PUNCT'),
#   ('on', 'ADP'),
#   ('this', 'DET'),
#   ('challenge', 'NOUN'),
#   (',', 'PUNCT'),
#   ('david', 'PROPN'),
#   ('.', 'PUNCT'),
#   ('"', 'PUNCT'),
#   ('kant', 'PROPN'),
#   ('say', 'VERB'),
#   (',', 'PUNCT'),
#   ('oh', 'INTJ'),
#   (',', 'PUNCT'),
#   ('you', 'PRON'),
#   ('think', 'VERB'),
#   ('the', 'DET'),
#   ('subject', 'NOUN'),
#   ('be', 'AUX'),
#   ('a', 'DET'),
#   ('blank', 'ADJ'),
#   ('slate', 'NOUN'),
#   ('?', 'PUNCT'),
#   ('you', 'PRON'),
#   ('think', 'VERB'),
#   ('that', 'SCONJ'),
#   ('you', 'PRON'),
#   ('start', 'VERB'),
#   ('out', 'ADP'),
#   ('empty', 'ADJ'),
#   ('?', 'PUNCT'),
#   ('well', 'INTJ'),
#   (',', 'PUNCT'),
#   ('perhaps', 'ADV'),
#   ('you', 'PRON'),
#   ('do', 'VERB'),
#   (',', 'PUNCT'),
#   ('but', 'CCONJ'),
#   ('you', 'PRON'),
#   ('still', 'ADV'),
#   ('start', 'VERB'),
#   ('with', 'ADP'),
#   ('the', 'DET'),
#   ('bowl', 'NOUN'),
#   ('.', 'PUNCT'),
#   ('hume', 'PROPN'),
#   ('be', 'AUX'),
#   ('right', 'ADJ'),
#   ('that', 'SCONJ'),
#   ('we', 'PRON'),
#   ('can', 'AUX'),
#   ('not', 'PART'),
#   ('look', 'VERB'),
#   ('inside', 'ADP'),
#   ('ourselves', 'PRON'),
#   ('and', 'CCONJ'),
#   ('experience', 'VERB'),
#   ('a', 'DET'),
#   ('subject', 'NOUN'),
#   (',', 'PUNCT'),
#   ('but', 'CCONJ'),
#   ('that', 'PRON'),
#   ('be', 'AUX'),
#   ('only', 'ADV'),
#   ('because', 'SCONJ'),
#   ('it', 'PRON'),
#   ('would', 'AUX'),
#   ('be', 'AUX'),
#   ('like', 'ADP'),
#   ('try', 'VERB'),
#   ('to', 'PART'),
#   ('put', 'VERB'),
#   ('the', 'DET'),
#   ('bowl', 'NOUN'),
#   ('inside', 'ADP'),
#   ('the', 'DET'),
#   ('bowl', 'NOUN'),
#   ('or', 'CCONJ'),
#   ('try', 'VERB'),
#   ('to', 'PART'),
#   ...]]

# %%
aca_words_percentage = []

aca_words_per_text = []

for oracion in oraciones_nlp:
        texto = list(zip(*oracion))[0]
        aca_words = academic(texto)
        aca_words_per_text+=[aca_words]
        aca_words_percentage += [len(aca_words)/len(texto)*100]

# %%
aca_words_percentage
# Out:
# [1.2872208436724566,
#  1.4324039474944907,
#  1.739595084011162,
#  1.9626615605552895,
#  0.7004669779853235,
#  0.6446991404011462,
#  1.2413289521723256,
#  1.2515472424700866,
#  2.8952597218279874,
#  1.495067817509248,
#  2.0415951154359857,
#  1.6172193135543922,
#  1.5839981500751534,
#  3.483606557377049,
#  3.152014895597819,
#  2.534259433076779,
#  2.0786262991414373,
#  2.1947449768160743,
#  2.6512788521522146,
#  1.1116662503122658,
#  1.3960819635217292,
#  1.4958560743885183,
#  1.261918115535614]

# %% [markdown]
# ## READABILITY
# Aquí deberían darme números entre 0 y 100

# %%
pip install py-readability-metrics
# Out:
# /usr/lib/python3/dist-packages/secretstorage/dhcrypto.py:15: CryptographyDeprecationWarning: int_from_bytes is deprecated, use int.from_bytes instead
#   from cryptography.utils import int_from_bytes
# /usr/lib/python3/dist-packages/secretstorage/util.py:19: CryptographyDeprecationWarning: int_from_bytes is deprecated, use int.from_bytes instead
#   from cryptography.utils import int_from_bytes
# Requirement already satisfied: py-readability-metrics in /home/cerdamara/.local/lib/python3.8/site-packages (1.4.5)
# Requirement already satisfied: nltk in /home/cerdamara/.local/lib/python3.8/site-packages (from py-readability-metrics) (3.7)
# Requirement already satisfied: joblib in /home/cerdamara/.local/lib/python3.8/site-packages (from nltk->py-readability-metrics) (1.1.0)
# Requirement already satisfied: click in /home/cerdamara/.local/lib/python3.8/site-packages (from nltk->py-readability-metrics) (7.1.2)
# Requirement already satisfied: tqdm in /home/cerdamara/.local/lib/python3.8/site-packages (from nltk->py-readability-metrics) (4.62.3)
# Requirement already satisfied: regex>=2021.8.3 in /home/cerdamara/.local/lib/python3.8/site-packages (from nltk->py-readability-metrics) (2022.1.18)
# Note: you may need to restart the kernel to use updated packages.

# %%
a = ((1,2),(3,4))
print(a)
b,c = zip(*a)
print(b)
# Out:
# ((1, 2), (3, 4))
# (1, 3)

# %%
##Flesch Kincaid Grade Level

from readability import Readability

#----
#El zip() devuelve dos valores, asi que lo tienes que guardar en dos variables antes de hacerles cualquier cosa. No se con cual de los dos valores
#te querias quedar, asi que voy a usar el primero
#Otra cosa es que tu funcion pedia string, asi que lo pase a string
#En el print fk.grade_lever, daba error, asi que asumi que era en realidad fk.grade_level y lo cambie
#----

#text = list(zip(*oracion))[0]

#----
text, aux = (zip(*oracion))
text = str(text)
#----

r=Readability(text)
fk=r.flesch_kincaid()

print(fk.score)
print(fk.grade_level)
# Out:
# 7.280973061503293
# 7

# %% [markdown]
# ## Passive Voice
# Esto debería separarme oraciones que están en voz pasiva

# %%
pip install https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.0.0/en_core_web_sm-3.0.0.tar.gz
# Out:
# /usr/lib/python3/dist-packages/secretstorage/dhcrypto.py:15: CryptographyDeprecationWarning: int_from_bytes is deprecated, use int.from_bytes instead
#   from cryptography.utils import int_from_bytes
# /usr/lib/python3/dist-packages/secretstorage/util.py:19: CryptographyDeprecationWarning: int_from_bytes is deprecated, use int.from_bytes instead
#   from cryptography.utils import int_from_bytes
# Collecting https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.0.0/en_core_web_sm-3.0.0.tar.gz
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.0.0/en_core_web_sm-3.0.0.tar.gz (13.7 MB)
#      |████████████████████████████████| 13.7 MB 999 kB/s eta 0:00:01
# Collecting spacy<3.1.0,>=3.0.0
#   Using cached spacy-3.0.7-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (6.5 MB)
# Requirement already satisfied: packaging>=20.0 in /home/cerdamara/.local/lib/python3.8/site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (20.9)
# Requirement already satisfied: srsly<3.0.0,>=2.4.1 in /home/cerdamara/.local/lib/python3.8/site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (2.4.2)
# Requirement already satisfied: typer<0.4.0,>=0.3.0 in /home/cerdamara/.local/lib/python3.8/site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (0.3.2)
# Requirement already satisfied: setuptools in /home/cerdamara/.local/lib/python3.8/site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (60.9.3)
# Requirement already satisfied: pathy>=0.3.5 in /home/cerdamara/.local/lib/python3.8/site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (0.6.1)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /home/cerdamara/.local/lib/python3.8/site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (1.0.6)
# Requirement already satisfied: thinc<8.1.0,>=8.0.3 in /home/cerdamara/.local/lib/python3.8/site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (8.0.13)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /home/cerdamara/.local/lib/python3.8/site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (4.62.3)
# Requirement already satisfied: blis<0.8.0,>=0.4.0 in /home/cerdamara/.local/lib/python3.8/site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (0.7.5)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /home/cerdamara/.local/lib/python3.8/site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (2.22.0)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.5 in /home/cerdamara/.local/lib/python3.8/site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (3.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /home/cerdamara/.local/lib/python3.8/site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (3.0.6)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /home/cerdamara/.local/lib/python3.8/site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (2.0.6)
# Requirement already satisfied: wasabi<1.1.0,>=0.8.1 in /home/cerdamara/.local/lib/python3.8/site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (0.9.0)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.4 in /home/cerdamara/.local/lib/python3.8/site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (2.0.6)
# Requirement already satisfied: jinja2 in /home/cerdamara/.local/lib/python3.8/site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (3.0.3)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4 in /home/cerdamara/.local/lib/python3.8/site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (1.8.2)
# Requirement already satisfied: numpy>=1.15.0 in /home/cerdamara/.local/lib/python3.8/site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (1.22.2)
# Requirement already satisfied: pyparsing>=2.0.2 in /home/cerdamara/.local/lib/python3.8/site-packages (from packaging>=20.0->spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (3.0.7)
# Requirement already satisfied: click<7.2.0,>=7.1.1 in /home/cerdamara/.local/lib/python3.8/site-packages (from typer<0.4.0,>=0.3.0->spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (7.1.2)
# Requirement already satisfied: smart-open<6.0.0,>=5.0.0 in /home/cerdamara/.local/lib/python3.8/site-packages (from pathy>=0.3.5->spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (5.2.1)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /home/cerdamara/.local/lib/python3.8/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /home/cerdamara/.local/lib/python3.8/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (2021.10.8)
# Requirement already satisfied: idna<2.9,>=2.5 in /home/cerdamara/.local/lib/python3.8/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (2.8)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /home/cerdamara/.local/lib/python3.8/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (1.25.11)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/cerdamara/.local/lib/python3.8/site-packages (from jinja2->spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (2.1.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /home/cerdamara/.local/lib/python3.8/site-packages (from pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4->spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (3.10.0.2)
# Building wheels for collected packages: en-core-web-sm
#   Building wheel for en-core-web-sm (setup.py) ... done
#   Created wheel for en-core-web-sm: filename=en_core_web_sm-3.0.0-py3-none-any.whl size=13704321 sha256=2a52cfeaca784405d246a720019c75e34a0edffb83071b287be7287e8b16dc65
#   Stored in directory: /home/cerdamara/.cache/pip/wheels/8b/21/c1/257748af7399fdaf1b2afc39c92fb839c436f42e67b656ff7e
# Successfully built en-core-web-sm
# ERROR: en-core-web-md 3.2.0 has requirement spacy<3.3.0,>=3.2.0, but you'll have spacy 3.0.7 which is incompatible.
# ERROR: en-core-web-lg 3.2.0 has requirement spacy<3.3.0,>=3.2.0, but you'll have spacy 3.0.7 which is incompatible.
# Installing collected packages: spacy, en-core-web-sm
#   Attempting uninstall: spacy
#     Found existing installation: spacy 3.2.2
#     Uninstalling spacy-3.2.2:
#       Successfully uninstalled spacy-3.2.2
#   Attempting uninstall: en-core-web-sm
#     Found existing installation: en-core-web-sm 3.2.0
#     Uninstalling en-core-web-sm-3.2.0:
#       Successfully uninstalled en-core-web-sm-3.2.0
# Successfully installed en-core-web-sm-3.0.0 spacy-3.0.7
# Note: you may need to restart the kernel to use updated packages.

# %%
import spacy
spacy.cli.download("en_core_web_md")
# Out:
# /usr/lib/python3/dist-packages/secretstorage/dhcrypto.py:15: CryptographyDeprecationWarning: int_from_bytes is deprecated, use int.from_bytes instead
#   from cryptography.utils import int_from_bytes
# /usr/lib/python3/dist-packages/secretstorage/util.py:19: CryptographyDeprecationWarning: int_from_bytes is deprecated, use int.from_bytes instead
#   from cryptography.utils import int_from_bytes
# Requirement already satisfied: en-core-web-md==3.2.0 from https://github.com/explosion/spacy-models/releases/download/en_core_web_md-3.2.0/en_core_web_md-3.2.0-py3-none-any.whl#egg=en_core_web_md==3.2.0 in /home/cerdamara/.local/lib/python3.8/site-packages (3.2.0)
# Collecting spacy<3.3.0,>=3.2.0
#   Using cached spacy-3.2.2-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (6.2 MB)
# Requirement already satisfied: numpy>=1.15.0 in /home/cerdamara/.local/lib/python3.8/site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-md==3.2.0) (1.22.2)
# Requirement already satisfied: jinja2 in /home/cerdamara/.local/lib/python3.8/site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-md==3.2.0) (3.0.3)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /home/cerdamara/.local/lib/python3.8/site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-md==3.2.0) (2.0.6)
# Requirement already satisfied: pathy>=0.3.5 in /home/cerdamara/.local/lib/python3.8/site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-md==3.2.0) (0.6.1)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /home/cerdamara/.local/lib/python3.8/site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-md==3.2.0) (1.0.1)
# Requirement already satisfied: blis<0.8.0,>=0.4.0 in /home/cerdamara/.local/lib/python3.8/site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-md==3.2.0) (0.7.5)
# Requirement already satisfied: thinc<8.1.0,>=8.0.12 in /home/cerdamara/.local/lib/python3.8/site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-md==3.2.0) (8.0.13)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /home/cerdamara/.local/lib/python3.8/site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-md==3.2.0) (4.62.3)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.8 in /home/cerdamara/.local/lib/python3.8/site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-md==3.2.0) (3.0.8)
# Requirement already satisfied: typer<0.5.0,>=0.3.0 in /home/cerdamara/.local/lib/python3.8/site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-md==3.2.0) (0.3.2)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /home/cerdamara/.local/lib/python3.8/site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-md==3.2.0) (3.3.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4 in /home/cerdamara/.local/lib/python3.8/site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-md==3.2.0) (1.8.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.1 in /home/cerdamara/.local/lib/python3.8/site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-md==3.2.0) (2.4.2)
# Requirement already satisfied: setuptools in /home/cerdamara/.local/lib/python3.8/site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-md==3.2.0) (60.9.3)
# Requirement already satisfied: packaging>=20.0 in /home/cerdamara/.local/lib/python3.8/site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-md==3.2.0) (20.9)
# Requirement already satisfied: wasabi<1.1.0,>=0.8.1 in /home/cerdamara/.local/lib/python3.8/site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-md==3.2.0) (0.9.0)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /home/cerdamara/.local/lib/python3.8/site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-md==3.2.0) (3.0.6)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /home/cerdamara/.local/lib/python3.8/site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-md==3.2.0) (1.0.6)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /home/cerdamara/.local/lib/python3.8/site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-md==3.2.0) (2.0.6)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /home/cerdamara/.local/lib/python3.8/site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-md==3.2.0) (2.22.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/cerdamara/.local/lib/python3.8/site-packages (from jinja2->spacy<3.3.0,>=3.2.0->en-core-web-md==3.2.0) (2.1.0)
# Requirement already satisfied: smart-open<6.0.0,>=5.0.0 in /home/cerdamara/.local/lib/python3.8/site-packages (from pathy>=0.3.5->spacy<3.3.0,>=3.2.0->en-core-web-md==3.2.0) (5.2.1)
# Requirement already satisfied: click<7.2.0,>=7.1.1 in /home/cerdamara/.local/lib/python3.8/site-packages (from typer<0.5.0,>=0.3.0->spacy<3.3.0,>=3.2.0->en-core-web-md==3.2.0) (7.1.2)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /home/cerdamara/.local/lib/python3.8/site-packages (from pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4->spacy<3.3.0,>=3.2.0->en-core-web-md==3.2.0) (3.10.0.2)
# Requirement already satisfied: pyparsing>=2.0.2 in /home/cerdamara/.local/lib/python3.8/site-packages (from packaging>=20.0->spacy<3.3.0,>=3.2.0->en-core-web-md==3.2.0) (3.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /home/cerdamara/.local/lib/python3.8/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.3.0,>=3.2.0->en-core-web-md==3.2.0) (2021.10.8)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /home/cerdamara/.local/lib/python3.8/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.3.0,>=3.2.0->en-core-web-md==3.2.0) (1.25.11)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /home/cerdamara/.local/lib/python3.8/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.3.0,>=3.2.0->en-core-web-md==3.2.0) (3.0.4)
# Requirement already satisfied: idna<2.9,>=2.5 in /home/cerdamara/.local/lib/python3.8/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.3.0,>=3.2.0->en-core-web-md==3.2.0) (2.8)
# ERROR: en-core-web-sm 3.0.0 has requirement spacy<3.1.0,>=3.0.0, but you'll have spacy 3.2.2 which is incompatible.
# Installing collected packages: spacy
#   Attempting uninstall: spacy
#     Found existing installation: spacy 3.0.7
#     Uninstalling spacy-3.0.7:
#       Successfully uninstalled spacy-3.0.7
# Successfully installed spacy-3.2.2
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_md')

# %%
import spacy
import pandas as pd

# function to check the type of sentence
def checkForSentType(inputSentence):   
    # running the model on sentence
    getDocFile = nlp(inputSentence)
    
    # getting the syntactic dependency 
    getAllTags = [token.dep_ for token in getDocFile]
    
    # checking for 'agent' tag
    checkPassiveTest = any(['agent' in sublist for sublist in getAllTags])
    
    # checking for 'nsubjpass' tag
    checkPassiveTestTwo = any(['nsubjpass' in sublist for sublist in getAllTags])
    return checkPassiveTest or checkPassiveTestTwo

# Spacy model imported
nlp = spacy.load('en_core_web_md')

# reading the list of test sentences
dfs = pd.read_csv(glob.glob('YTessays/*.txt'))
sentences = dfs.values.tolist()

finalResult = []

# checking each sentence for its type
for sentence in sentences:
    result = checkForSentType(str(sentence))
    if(result):
        finalResult.append('Passive Sentence')
    else:
        finalResult.append('Active Sentence')
        
# storing the result in a new file and converting to csv
newDf = pd.DataFrame({'Sentences':sentences,'Answers':finalResult})

newDf.to_csv('Sentence_Identified.csv')
